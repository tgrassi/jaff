# %%
from jaff.network import Network

# %%
net = Network("../networks/test2.dat")
# Out:
# Welcome to JAFF: Just Another Fancy Format!
#
# INFO: Loading network from ../networks/test2.dat
# INFO: Network label: test2
# Parsing test2: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 621.61 lines/s]
# INFO: Variables found: av, tgas
# INFO: Loaded 2 reactions
# INFO: Loaded 0 photo-chemistry reactions
#
# All done!

# %%
from jaff.builder import Builder

b = Builder(net)
b.build(template="python_solve_ivp")
# Out:
# Building network with template: python_solve_ivp
# Preprocessing /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/src/jaff/templates/preprocessor/python_solve_ivp/commons.py -> /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples/commons.py
# Preprocessing /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/src/jaff/templates/preprocessor/python_solve_ivp/rates.py -> /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples/rates.py
# Preprocessing /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/src/jaff/templates/preprocessor/python_solve_ivp/fluxes.py -> /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples/fluxes.py
# Preprocessing /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/src/jaff/templates/preprocessor/python_solve_ivp/ode.py -> /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples/ode.py
# Copying /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/src/jaff/templates/preprocessor/python_solve_ivp/main.py to /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples
# Network built successfully using template 'python_solve_ivp'.
# Output files are located in: /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples
# '/home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples'
