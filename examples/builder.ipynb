# %%
from jaff import Network

# %%
net = Network("../networks/demos/demo2.jet")
# Out:
# ░░█ ▄▀█ █▀▀ █▀▀
# █▄█ █▀█ █▀░ █▀░
#
# Just Another Flexible Format!
#
# INFO     Loading network from /home/anish/External/programming/research/jaff/worktrees/feature_photo_dissociation/networks/demos/demo2.jet
# INFO     Network label: demo2
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO     Variables found: av, tgas
# INFO     Loaded 2 reactions
# INFO     Loaded 0 photo-chemistry reactions
# INFO     Network loaded successfully!

# %%
from jaff import Builder

b = Builder(net)
b.build(template="python_solve_ivp")
# Out:
# Building network with template: python_solve_ivp
# INFO     Preprocessing /home/anish/External/programming/research/jaff/worktrees/feature_photo_dissociation/src/jaff/templates/preprocessor/python_solve_ivp/commons.py -> /home/anish/External/programming/research/jaff/worktrees/feature_photo_dissociation/examples/commons.py
# INFO     Preprocessing /home/anish/External/programming/research/jaff/worktrees/feature_photo_dissociation/src/jaff/templates/preprocessor/python_solve_ivp/rates.py -> /home/anish/External/programming/research/jaff/worktrees/feature_photo_dissociation/examples/rates.py
# INFO     Preprocessing /home/anish/External/programming/research/jaff/worktrees/feature_photo_dissociation/src/jaff/templates/preprocessor/python_solve_ivp/fluxes.py -> /home/anish/External/programming/research/jaff/worktrees/feature_photo_dissociation/examples/fluxes.py
# ...
