# %%
from jaff.network import Network

# %%
net = Network("../networks/demos/demo2.dat")
# Out:
# Welcome to
#
# ░░█ ▄▀█ █▀▀ █▀▀
# █▄█ █▀█ █▀░ █▀░
#
# Just Another Fancy Format!
#
# INFO: Loading network from /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/networks/demos/demo2.dat
# INFO: Network label: demo2
# Parsing demo2.dat: 2 lines [00:00, 41323.19 lines/s]
# Creating demo2 network: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1499.84 reactions/s]
# INFO: Variables found: av, tgas
# INFO: Loaded 2 reactions
# INFO: Loaded 0 photo-chemistry reactions
#
# All done!

# %%
from jaff.builder import Builder

b = Builder(net)
b.build(template="python_solve_ivp")
# Out:
# Building network with template: python_solve_ivp
# Preprocessing /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/src/jaff/templates/preprocessor/python_solve_ivp/commons.py -> /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/examples/commons.py
# Preprocessing /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/src/jaff/templates/preprocessor/python_solve_ivp/rates.py -> /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/examples/rates.py
# Preprocessing /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/src/jaff/templates/preprocessor/python_solve_ivp/fluxes.py -> /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/examples/fluxes.py
# Preprocessing /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/src/jaff/templates/preprocessor/python_solve_ivp/ode.py -> /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/examples/ode.py
# Copying /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/src/jaff/templates/preprocessor/python_solve_ivp/main.py to /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/examples
# Network built successfully using template 'python_solve_ivp'.
# Output files are located in: /home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/examples
# '/home/anish/External/programming/research/jaff/worktrees/refractor_network_cleanup/examples'
