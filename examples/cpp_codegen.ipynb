# %% [markdown]
# # Generating C++ Kokkos Chemistry Solvers with JAFF
#
# This notebook demonstrates how to use JAFF to generate C++ code that uses the Kokkos-kernels BDF solver for solving chemical reaction networks. We'll use the `react_COthin` network as an example, which contains 37 species.
#
# ## Overview
#
# The Kokkos output plugin generates:
# - **chemistry_ode.hpp**: Chemistry ODE system class with evaluate_function and evaluate_jacobian methods
# - **chemistry_ode.cpp**: Main executable that sets up and runs the BDF solver
# - **CMakeLists.txt**: Build configuration for Kokkos and Kokkos-kernels dependencies
#
# The generated code is compatible with the Kokkos-kernels BDF solver for stiff ODEs.

# %% [markdown]
# ## Step 1: Load the Chemical Network
#
# First, let's load the react_COthin network, which is a carbon-oxygen chemistry network in KROME format.

# %%
import os

from jaff.builder import Builder
from jaff.network import Network

# Load the test2 network
network = Network("../networks/react_COthin")

print(f"Network loaded: {network.label}")
print(f"Number of species: {network.get_number_of_species()}")
print(f"Number of reactions: {len(network.reactions)}")
# Out:
# Welcome to JAFF: Just Another Fancy Format!
#
# INFO: Loading network from ../networks/react_COthin
# INFO: Network label: react_COthin
# Parsing react_COthin:   3%|██▎                                                                        | 11/350 [00:00<00:03, 104.18 lines/s]
# INFO: KROME variable detected: @var:Hnuclei = get_Hnuclei(n(:))
# INFO: KROME variable detected: @var: Te = Tgas*8.617343d-5
# INFO: KROME variable detected: @var: invT = 1d0/Tgas
# INFO: KROME variable detected: @var: lnTe = log(Te)
# INFO: KROME variable detected: @var: T = Tgas
# INFO: KROME format detected: @format:idx,R,R,R,P,P,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,R,P,P,P,Tmin,Tmax,rate
# INFO: KROME variable detected: @var:invTe=1d0/Te
# INFO: KROME variable detected: @var:logT=log10(Tgas)
# INFO: KROME variable detected: @var:invsqrT=1d0/sqrt(Tgas)
# INFO: KROME variable detected: @var:kl11 = 1d1**(-27.029d0+3.801d0*logT-29487d0*invT)
# INFO: KROME variable detected: @var:kh11 = 1d1**(-2.729d0-1.75d0*logT-23474d0*invT)
# INFO: KROME variable detected: @var:ncr11 = 1d1**(5.0792d0*(1d0-1.23d-5*(Tgas-2d3)))
# INFO: KROME variable detected: @var:a11=1.d0/(1.d0+(Hnuclei/(ncr11+1d-40)))
# Parsing react_COthin:  11%|████████▎                                                                  | 39/350 [00:00<00:02, 105.99 lines/s]
# INFO: KROME format detected: @format:idx,R,R,R,P,P,P,Tmin,Tmax,rate
# Parsing react_COthin:  17%|█████████████                                                              | 61/350 [00:00<00:02, 100.76 lines/s]
# INFO: KROME variable detected: @var:kl21 = 1.18d-10*exp(-6.95d4*invT)
# INFO: KROME variable detected: @var:kh21 = 8.125d-8*invsqrT*exp(-5.2d4*invT)*(1.d0-exp(-6d3*invT))
# INFO: KROME variable detected: @var:ncr21 = 1d1**(4.845d0-1.3d0*log10(T*1d-4)+1.62d0*log10(T*1d-4)**2)
# INFO: KROME variable detected: @var:a21=1.d0/(1.d0+(Hnuclei/(ncr21+1d-40)))
# INFO: KROME variable detected: @var:u1 = 11.26d0*invTe
# INFO: KROME variable detected: @var:u2 = 8.2d0*invTe
# INFO: KROME variable detected: @var:u3 = 13.6*invTe
# INFO: KROME format detected: @format:idx,R,R,R,P,P,P,P,Tmin,Tmax,rate
# Parsing react_COthin:  40%|█████████████████████████████▌                                            | 140/350 [00:00<00:00, 216.53 lines/s]
# INFO: KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# Parsing react_COthin:  75%|███████████████████████████████████████████████████████▏                  | 261/350 [00:01<00:00, 417.79 lines/s]
# INFO: KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# INFO: KROME format detected: @format:idx,R,R,P,rate
# INFO: KROME variable detected: @var:fA = 1d0/(1d0+1d4*exp(-6d2/(user_Tdust+1d-40)))
# INFO: KROME format detected: @format:idx,R,P,P,rate
# INFO: KROME variable detected: @var: user_H2self = fselfH2(1.87d21*(merge(n(idx_H2),n_global(idx_H2),n(idx_H2) > 0.0_8)*1d-3)**(2./3.), 1d5)
# Parsing react_COthin: 100%|██████████████████████████████████████████████████████████████████████████| 350/350 [00:01<00:00, 263.48 lines/s]
# INFO: KROME variable detected: @var: HnOj = fHnOj(user_Av)
# INFO: KROME format detected: @format:idx,R,P,P,P,rate
# INFO: KROME variable detected: @var:ntot=sum(n(1:nmols))
# WARNING: Could not parse variable (invalid syntax (<unknown>, line 1)), using string instead
# INFO: KROME format detected: @format:idx,R,R,P,Tmin,Tmax,rate
# WARNING: Variable ntot not replaced because it is a string, not a sympy expression
# WARNING: Variable ntot not replaced because it is a string, not a sympy expression
# WARNING: Variable ntot not replaced because it is a string, not a sympy expression
# WARNING: Variable ntot not replaced because it is a string, not a sympy expression
# WARNING: Variable ntot not replaced because it is a string, not a sympy expression
# WARNING: Variable ntot not replaced because it is a string, not a sympy expression
# WARNING: Variable ntot not replaced because it is a string, not a sympy expression
# WARNING: Variable ntot not replaced because it is a string, not a sympy expression
# WARNING: Variable ntot not replaced because it is a string, not a sympy expression
# WARNING: Variable ntot not replaced because it is a string, not a sympy expression
# WARNING: Variable ntot not replaced because it is a string, not a sympy expression
# INFO: Variables found: av, crate, tdust, tgas
# INFO: Loaded 287 reactions
# INFO: Loaded 0 photo-chemistry reactions
# WARNING: Isomer detected: HOC+ HCO+
# WARNING: Duplicate reaction found: O + H -> OH
# WARNING: Duplicate reaction found: O + O -> O2
# WARNING: Duplicate reaction found: OH + H -> H2O
#
# All done!
#
# Network loaded: react_COthin
# Number of species: 37
# Number of reactions: 287

# %% [markdown]
# ## Step 2: Examine Network Properties
#
# Let's examine some properties of the network to understand what we're working with.

# %%
for i, species in enumerate(network.species):
    print(f"  {i}: {species.name} (mass: {species.mass:.2e}, charge: {species.charge})")

print(f"\nTotal species: {len(network.species)}")
# Out:
#   0: H (mass: 1.67e-24, charge: 0)
#   1: e- (mass: 9.11e-28, charge: -1)
#   2: H+ (mass: 1.67e-24, charge: 1)
#   3: He (mass: 6.65e-24, charge: 0)
#   4: He+ (mass: 6.65e-24, charge: 1)
#   5: He++ (mass: 6.65e-24, charge: 2)
#   6: H2 (mass: 3.35e-24, charge: 0)
#   7: H2+ (mass: 3.35e-24, charge: 1)
#   8: H- (mass: 1.67e-24, charge: -1)
#   9: C+ (mass: 1.99e-23, charge: 1)
#   10: C (mass: 1.99e-23, charge: 0)
#   11: Si+ (mass: 4.66e-23, charge: 1)
#   12: Si (mass: 4.66e-23, charge: 0)
#   13: O+ (mass: 2.66e-23, charge: 1)
#   14: O (mass: 2.66e-23, charge: 0)
#   15: Si++ (mass: 4.66e-23, charge: 2)
#   16: OH (mass: 2.82e-23, charge: 0)
#   17: HOC+ (mass: 4.82e-23, charge: 1)
#   18: HCO+ (mass: 4.82e-23, charge: 1)
#   19: CO (mass: 4.65e-23, charge: 0)
#   20: CH (mass: 2.16e-23, charge: 0)
#   21: CH2 (mass: 2.33e-23, charge: 0)
#   22: C2 (mass: 3.99e-23, charge: 0)
#   23: HCO (mass: 4.82e-23, charge: 0)
#   24: H2O (mass: 2.99e-23, charge: 0)
#   25: O2 (mass: 5.31e-23, charge: 0)
#   26: H3+ (mass: 5.02e-24, charge: 1)
#   27: CH+ (mass: 2.16e-23, charge: 1)
#   28: CH2+ (mass: 2.33e-23, charge: 1)
#   29: CO+ (mass: 4.65e-23, charge: 1)
#   30: CH3+ (mass: 2.50e-23, charge: 1)
#   31: OH+ (mass: 2.82e-23, charge: 1)
#   32: H2O+ (mass: 2.99e-23, charge: 1)
#   33: H3O+ (mass: 3.16e-23, charge: 1)
#   34: O2+ (mass: 5.31e-23, charge: 1)
#   35: C- (mass: 1.99e-23, charge: -1)
#   36: O- (mass: 2.66e-23, charge: -1)
#
# Total species: 37

# %%
# Show a few example reactions
for i, reaction in enumerate(network.reactions[:10]):
    reactants = " + ".join([f"{r.name}" for r in reaction.reactants])
    products = " + ".join([f"{p.name}" for p in reaction.products])
    print(f"  {i + 1}: {reactants} -> {products}")
    print(f"      Rate: {reaction.rate}")
    print()
# Out:
#   1: H + e- -> H+ + e- + e-
#       Rate: 5.90824386372651e-70*exp(-2.03914985e-6*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**8 + 0.000111954395*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**7 - 0.00263197617*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**6 + 0.0348255977*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**5 - 0.2877056*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**4 + 1.56315498*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**3 - 5.73932875*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**2)*Max(2.73, Min(100000000.0, tgas))**13.536556
#
#   2: H+ + e- -> H
#       Rate: 1.49810881307214e-10/Max(2.73, Min(5500.0, tgas))**0.6353
#
#   3: H+ + e- -> H
#       Rate: 3.286733702438273e-10*exp(-3.071135243196595e-9*log(8.617343e-5*Max(5500.0, Min(100000000.0, tgas)))**9 - 1.856767039775261e-8*log(8.617343e-5*Max(5500.0, Min(100000000.0, tgas)))**8 + 5.755614137575758e-7*log(8.617343e-5*Max(5500.0, Min(100000000.0, tgas)))**7 + 4.989108920299513e-6*log(8.617343e-5*Max(5500.0, Min(100000000.0, tgas)))**6 - 1.421502914054107e-5*log(8.617343e-5*Max(5500.0, Min(100000000.0, tgas)))**5 - 0.0003212605213188796*log(8.617343e-5*Max(5500.0, Min(100000000.0, tgas)))**4 - 0.002380861877349834*log(8.617343e-5*Max(5500.0, Min(100000000.0, tgas)))**3 - 0.02026044731984691*log(8.617343e-5*Max(5500.0, Min(100000000.0, tgas)))**2)/Max(5500.0, Min(100000000.0, tgas))**0.7241125657826851
#
#   4: He + e- -> He+ + e- + e-
#       Rate: 4.35240791147676e-117*exp(-3.64916141e-6*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**8 + 0.000206723616*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**7 - 0.0050090561*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**6 + 0.0679539123*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**5 - 0.56851189*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**4 + 3.05803875*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**3 - 10.7532302*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**2)*Max(2.73, Min(100000000.0, tgas))**23.91596563
#
#   5: He+ + e- -> He
#       Rate: 1.49810881307214e-10/Max(2.73, Min(9280.0, tgas))**0.6353
#
#   6: He+ + e- -> He
#       Rate: 0.0019251326128586*(1.0 + 0.3*exp(-93988.7015019247/Max(9280.0, Min(100000000.0, tgas))))*exp(-469943.5075096421/Max(9280.0, Min(100000000.0, tgas)))/Max(9280.0, Min(100000000.0, tgas))**1.5 + 1.49810881307214e-10/Max(9280.0, Min(100000000.0, tgas))**0.6353
#
#   7: He+ + e- -> He++ + e- + e-
#       Rate: 3.857187335968145e-209*exp(-3.165581065665e-6*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**8 + 0.0001975705312221*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**7 - 0.005324020628287001*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**6 + 0.08113042097303*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**5 - 0.7692466334492*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**4 + 4.701626486759002*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**3 - 18.48066993568*log(8.617343e-5*Max(2.73, Min(100000000.0, tgas)))**2)*Max(2.73, Min(100000000.0, tgas))**43.93347632635
#
#   8: He+ + H -> He + H+
#       Rate: 3.00351426766844e-16*tgas**0.25
#
#   9: He + H+ -> He+ + H
#       Rate: 1.26e-9*exp(-127500.0/Min(10000.0, tgas))/Min(10000.0, tgas)**0.75
#
#   10: He + H+ -> He+ + H
#       Rate: 4.0e-37*Max(10000.0, tgas)**4.74

# %% [markdown]
# ## Step 3: Generate C++ Kokkos Code
#
# Now let's use the Builder to generate C++ code using the `kokkos_ode` template.

# %%
# Create builder and generate Kokkos C++ code
builder = Builder(network)
builds_dir = builder.build(template="kokkos_ode")

print("\nC++ Kokkos code generated successfully!")
print(f"Generated files are located at {builds_dir}")
# Out:
# Building network with template: kokkos_ode
# Preprocessing /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/src/jaff/templates/preprocessor/kokkos_ode/chemistry_ode.hpp -> /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples/chemistry_ode.hpp
# Preprocessing /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/src/jaff/templates/preprocessor/kokkos_ode/chemistry_ode.cpp -> /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples/chemistry_ode.cpp
# Preprocessing /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/src/jaff/templates/preprocessor/kokkos_ode/CMakeLists.txt -> /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples/CMakeLists.txt
# Network built successfully using template 'kokkos_ode'.
# Output files are located in: /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples
#
# C++ Kokkos code generated successfully!
# Generated files are located at /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples

# %% [markdown]
# ## Step 4: Examine Generated Files
#
# Let's look at the structure and content of the generated files.

# %%
# List generated files
generated_files = [
    f for f in os.listdir(builds_dir) if f.endswith((".cpp", ".hpp", ".txt"))
]

print("Generated files:")
for file in sorted(generated_files):
    filepath = os.path.join(builds_dir, file)
    size = os.path.getsize(filepath)
    print(f"  {file:20} ({size:,} bytes)")
# Out:
# Generated files:
#   CMakeLists.txt       (2,371 bytes)
#   chemistry_ode.cpp    (9,915 bytes)
#   chemistry_ode.hpp    (182,236 bytes)

# %% [markdown]
# ## Step 5: Understanding the Generated Code Structure
#
# Let's examine key components of the generated chemistry solver.

# %%
# Show the ChemistryODE class definition
with open(builds_dir + "/chemistry_ode.hpp", "r") as f:
    lines = f.readlines()

# Find the class definition
class_start = None
for i, line in enumerate(lines):
    if "struct ChemistryODE" in line:
        class_start = i
        break

if class_start:
    print("ChemistryODE class structure:")
    print("=" * 50)
    # Show class definition and methods
    brace_count = 0
    for i in range(class_start, len(lines)):
        line = lines[i].rstrip()
        print(f"{i + 1:2d}: {line}")

        if "{" in line:
            brace_count += line.count("{")
        if "}" in line:
            brace_count -= line.count("}")
            if brace_count == 0:
                break
# Out:
# ChemistryODE class structure:
# ==================================================
# 14: struct ChemistryODE {
# 15:     // Number of species in the chemical network
# 16:     // PREPROCESS_NUM_SPECIES
# 17:
# 18:     static constexpr int neqs = 37;
# 19:
# 20:     // PREPROCESS_END
# 21:
# 22:     using state_type = std::array<integrators::Real, neqs>;
# 23:     using rhs_type = std::array<integrators::Real, neqs>;
# 24:     using jacobian_type = std::array<std::array<integrators::Real, neqs>, neqs>;
# 25:
# 26:     // Species indices and common constants
# 27:     // PREPROCESS_COMMONS
# 28:
# 29:     static constexpr int idx_h = 0;
# 30:     static constexpr int idx_e = 1;
# 31:     static constexpr int idx_hj = 2;
# 32:     static constexpr int idx_he = 3;
# 33:     static constexpr int idx_hej = 4;
# 34:     static constexpr int idx_hejj = 5;
# 35:     static constexpr int idx_h2 = 6;
# 36:     static constexpr int idx_h2j = 7;
# 37:     static constexpr int idx_hk = 8;
# 38:     static constexpr int idx_cj = 9;
# 39:     static constexpr int idx_c = 10;
# 40:     static constexpr int idx_sij = 11;
# 41:     static constexpr int idx_si = 12;
# 42:     static constexpr int idx_oj = 13;
# 43:     static constexpr int idx_o = 14;
# 44:     static constexpr int idx_sijj = 15;
# 45:     static constexpr int idx_oh = 16;
# 46:     static constexpr int idx_hocj = 17;
# 47:     static constexpr int idx_hcoj = 18;
# 48:     static constexpr int idx_co = 19;
# 49:     static constexpr int idx_ch = 20;
# 50:     static constexpr int idx_ch2 = 21;
# 51:     static constexpr int idx_c2 = 22;
# 52:     static constexpr int idx_hco = 23;
# 53:     static constexpr int idx_h2o = 24;
# 54:     static constexpr int idx_o2 = 25;
# 55:     static constexpr int idx_h3j = 26;
# 56:     static constexpr int idx_chj = 27;
# 57:     static constexpr int idx_ch2j = 28;
# 58:     static constexpr int idx_coj = 29;
# 59:     static constexpr int idx_ch3j = 30;
# 60:     static constexpr int idx_ohj = 31;
# 61:     static constexpr int idx_h2oj = 32;
# 62:     static constexpr int idx_h3oj = 33;
# 63:     static constexpr int idx_o2j = 34;
# 64:     static constexpr int idx_ck = 35;
# 65:     static constexpr int idx_ok = 36;
# 66:     static constexpr int nspecs = 37;
# 67:     static constexpr int nreactions = 287;
# 68:
# 69:     // Common chemistry variables used in rate expressions
# 70:     // These should typically be passed as parameters or computed from the state
# 71:     static constexpr double DEFAULT_TEMPERATURE = 300.0;  // Default gas temperature in K
# 72:     static constexpr double DEFAULT_AV = 1.0;             // Default visual extinction
# 73:     static constexpr double DEFAULT_CRATE = 1.3e-17;      // Default cosmic ray ionization rate
# 74:
# 75:     // PREPROCESS_END
# 76:
# 77:     // Evaluate the ODE right-hand side: dy/dt = f(t, y)
# 78:     static void rhs(const integrators::Real /*t*/, const state_type& y, rhs_type& f) {
# 79:         // PREPROCESS_TEMP_VARS
# 80:
# 81:         // Temperature and environment variables used in chemical reactions
# 82:         // T is expected to be passed as a parameter or computed from the state
# 83:         const double tgas = DEFAULT_TEMPERATURE;
# 84:         const double tdust = DEFAULT_TEMPERATURE;
# 85:         const double av = DEFAULT_AV;  // Visual extinction
# 86:         const double crate = DEFAULT_CRATE;  // Cosmic ray ionization rate
# 87:
# 88:         // PREPROCESS_END
# 89:
# 90:         // Alias species concentrations to `nden` to match generated code
# 91:         const auto& nden = y;
# 92:
# 93:         // Compute reaction rates
# 94:         // PREPROCESS_NUM_REACTIONS
# 95:
# 96:         double k[287];
# 97:
# 98:         // PREPROCESS_END
# 99:
# 100:         // PREPROCESS_RATES
# 101:
# 102:         const double x0 = std::min(100000000.0, tgas);
# 103:         const double x1 = std::max(2.73, x0);
# 104:         const double x2 = std::log(8.6173430000000006e-5*x1);
# 105:         const double x3 = std::pow(x2, 2);
# 106:         const double x4 = std::pow(x2, 3);
# 107:         const double x5 = std::pow(x2, 4);
# 108:         const double x6 = std::pow(x2, 5);
# 109:         const double x7 = std::pow(x2, 6);
# 110:         const double x8 = std::max(5500.0, x0);
# 111:         const double x9 = std::log(8.6173430000000006e-5*x8);
# 112:         const double x10 = std::pow(x9, 2);
# 113:         const double x11 = std::max(9280.0, x0);
# 114:         const double x12 = 1.0/x11;
# 115:         const double x13 = std::min(10000.0, tgas);
# 116:         const double x14 = 1.0/tgas;
# 117:         const double x15 = std::log(tgas);
# 118:         const double x16 = M_LN10;
# 119:         const double x17 = 1.0/x16;
# 120:         const double x18 = nden[0] + nden[2] + nden[8] + nden[16] + nden[17] + nden[18] + nden[20] + nden[23] + nden[27] + nden[31];
# 121:         const double x19 = x18 + 2*nden[6] + 2*nden[7] + 2*nden[21] + 2*nden[24] + 3*nden[26] + 2*nden[28] + 3*nden[30] + 2*nden[32] + 3*nden[33];
# 122:         const double x20 = 1.0/(x19/(std::pow(10.0, 5.2041483199999998 - 6.247416000000001e-5*tgas) + 9.9999999999999993e-41) + 1.0);
# 123:         const double x21 = std::sqrt(tgas);
# 124:         const double x22 = std::exp(-52000.0*x14);
# 125:         const double x23 = std::pow(x1, 0.69999999999999996);
# 126:         const double x24 = std::max(1160.0, x0);
# 127:         const double x25 = std::log(8.6173430000000006e-5*x24);
# 128:         const double x26 = std::pow(x25, 2);
# 129:         const double x27 = std::pow(x25, 3);
# 130:         const double x28 = std::pow(x25, 4);
# 131:         const double x29 = std::pow(x25, 5);
# 132:         const double x30 = 1.7793594306049821e-5*std::max(6700.0, x0);
# 133:         const double x31 = std::max(3480.0, x0);
# 134:         const double x32 = std::log(8.6173430000000006e-5*x31);
# 135:         const double x33 = std::pow(x32, 2);
# 136:         const double x34 = std::sqrt(x1);
# 137:         const double x35 = 1.0/x1;
# 138:         const double x36 = std::pow(x1, -1.0/2.0);
# 139:         const double x37 = std::log(0.0001*tgas);
# 140:         const double x38 = 1.0/(x19/(std::pow(10.0, -1.3*x17*x37 + 4.8449999999999998 + 1.6200000000000001*std::pow(x37, 2)/std::pow(x16, 2)) + 9.9999999999999993e-41) + 1.0);
# 141:         const double x39 = std::exp(-6000.0*x14);
# 142:         const double x40 = std::min(300.0, tgas);
# 143:         const double x41 = std::pow(std::max(2.73, x40), -0.38);
# 144:         const double x42 = 1.0/std::max(300.0, x0);
# 145:         const double x43 = std::max(7950.0, std::min(21140.0, tgas));
# 146:         const double x44 = std::min(2000.0, tgas);
# 147:         const double x45 = std::max(2000.0, tgas);
# 148:         const double x46 = std::max(400.0, x0);
# 149:         const double x47 = 1.0/x46;
# 150:         const double x48 = std::pow(x1, -0.25);
# 151:         const double x49 = 130666.72639118577*x35;
# 152:         const double x50 = 95156.941066405256*x35;
# 153:         const double x51 = 157821.26811013557*x35;
# 154:         const double x52 = std::min(1000000.0, tgas);
# 155:         const double x53 = std::pow(x52, 0.23999999999999999)*(3.1699999999999999*std::exp(4.1839999999999999e-7*x52) + 1.0);
# 156:         const double x54 = std::max(10.0, tgas);
# 157:         const double x55 = 1.0/x54;
# 158:         const double x56 = 1.0/x45;
# 159:         const double x57 = std::exp(-270.0*x14);
# 160:         const double x58 = std::max(300.0, tgas);
# 161:         const double x59 = std::max(200.0, std::min(350.0, tgas));
# 162:         const double x60 = std::max(295.0, tgas);
# 163:         const double x61 = std::sqrt(tgas);
# 164:         const double x62 = 5.9203000000000005e-14*tgas;
# 165:         const double x63 = std::pow(tgas, 0.16669999999999999);
# 166:         const double x64 = std::pow(tgas, 1.5);
# 167:         const double x65 = std::pow(tgas, -0.156)*std::exp(-1.4099999999999999*x14);
# 168:         const double x66 = std::pow(x54, -0.5);
# 169:         const double x67 = std::sqrt(1.0/std::min(150.0, tgas));
# 170:         const double x68 = 2.0548002110835724e-8*x67 + 1.0943e-9;
# 171:         const double x69 = std::max(150.0, tgas);
# 172:         const double x70 = std::pow(x69, -0.5);
# 173:         const double x71 = 1.0/x69;
# 174:         const double x72 = 4.1682227902618297e-9*x70 + 1.0000940075e-7*x71 + 1.765e-9;
# 175:         const double x73 = 1.1234460077595736e-8*x67 + 5.9830000000000009e-10;
# 176:         const double x74 = 2.2789433385850798e-9*x70 + 5.4679360630822505e-8*x71 + 9.6500000000000008e-10;
# 177:         const double x75 = 2.2906988549538973e-8*x66 + 3.1794839999999998e-10;
# 178:         const double x76 = 1.0/x61;
# 179:         const double x77 = 3.9837168574084182e-6*x76;
# 180:         const double x78 = std::pow(tgas, -0.52000000000000002);
# 181:         const double x79 = std::pow(tgas, -0.59999999999999998);
# 182:         const double x80 = std::pow(tgas, -0.64000000000000001);
# 183:         const double x81 = 1.0/x58;
# 184:         const double x82 = std::pow(tgas, 2);
# 185:         const double x83 = std::exp(-0.5*av);
# 186:         const double x84 = std::pow(nden[6], 0.66666666666666663);
# 187:         const double x85 = std::sqrt(37400.000000000015*x84 + 1);
# 188:         const double x86 = std::exp(-1.8*av);
# 189:         const double x87 = std::exp(-2.2999999999999998*av);
# 190:         const double x88 = std::exp(-2.7999999999999998*av);
# 191:         const double x89 = std::exp(-1.7*av);
# 192:         const double x90 = 1.0000000000000001e-9*x89;
# 193:         const double x91 = ((av < 15) ? (
# 194:            std::exp(av*(0.016500000000000001*av - 2.5499999999999998))
# 195:         )
# 196:         : (
# 197:            x88
# 198:         ));
# 199:         const double x92 = 5.0000000000000002e-11*x91;
# 200:         const double x93 = 2.5000000000000001e-11*x91;
# 201:         const double x94 = 0.93000000000000005*crate;
# 202:         const double x95 = x18 + nden[1] + nden[3] + nden[4] + nden[5] + nden[6] + nden[7] + nden[9] + nden[10] + nden[11] + nden[12] + nden[13] + nden[14] + nden[15] + nden[19] + nden[21] + nden[22] + nden[24] + nden[25] + nden[26] + nden[28] + nden[29] + nden[30] + nden[32] + nden[33] + nden[34] + nden[35] + nden[36];
# 203:         const double x96 = std::max(5000.0, tgas);
# 204:         const double x97 = std::pow(x44, -3.0800000000000001)*x95;
# 205:         const double x98 = std::pow(x45, -3.0800000000000001)*x95*std::exp(2114.0*x56);
# 206:         const double x99 = 2.6249085452559344e-19*x97;
# 207:         const double x100 = 9.1190004656618504e-20*x98;
# 208:         const double x101 = x14*x95;
# 209:         k[0] = 5.9082438637265071e-70*std::pow(x1, 13.536555999999999)*std::exp(x3*(1.56315498*x2 - 0.28770560000000001*x3 + 0.034825597700000002*x4 - 0.00263197617*x5 + 0.000111954395*x6 - 2.0391498499999999e-6*x7 - 5.7393287500000003));
# 210:         k[1] = 1.4981088130721367e-10*std::pow(std::max(2.73, std::min(5500.0, tgas)), -0.63529999999999998);
# 211:         k[2] = 3.2867337024382733e-10*std::pow(x8, -0.7241125657826851)*std::exp(x10*(-0.0003212605213188796*x10 - 3.071135243196595e-9*std::pow(x9, 7) - 1.856767039775261e-8*std::pow(x9, 6) + 5.755614137575758e-7*std::pow(x9, 5) + 4.989108920299513e-6*std::pow(x9, 4) - 1.421502914054107e-5*std::pow(x9, 3) - 0.002380861877349834*x9 - 0.02026044731984691));
# 212:         k[3] = 4.3524079114767552e-117*std::pow(x1, 23.915965629999999)*std::exp(x3*(3.0580387500000001*x2 - 0.56851189000000002*x3 + 0.067953912300000002*x4 - 0.0050090561*x5 + 0.000206723616*x6 - 3.6491614100000001e-6*x7 - 10.753230200000001));
# 213:         k[4] = 1.4981088130721367e-10*std::pow(std::max(2.73, std::min(9280.0, tgas)), -0.63529999999999998);
# 214:         k[5] = 0.0019251326128585952*std::pow(x11, -1.5)*(1.0 + 0.29999999999999999*std::exp(-93988.701501924661*x12))*std::exp(-469943.50750964211*x12) + 1.4981088130721367e-10*std::pow(x11, -0.63529999999999998);
# 215:         k[6] = 3.8571873359681448e-209*std::pow(x1, 43.933476326349997)*std::exp(x3*(4.701626486759002*x2 - 0.76924663344919997*x3 + 0.081130420973029999*x4 - 0.005324020628287001*x5 + 0.00019757053122209999*x6 - 3.1655810656650001e-6*x7 - 18.480669935680002));
# 216:         k[7] = 3.0035142676684429e-16*std::pow(tgas, 0.25);
# 217:         k[8] = 1.26e-9*std::pow(x13, -0.75)*std::exp(-127500.0/x13);
# 218:         k[9] = 4.0000000000000003e-37*std::pow(std::max(10000.0, tgas), 4.7400000000000002);
# 219:         k[10] = std::pow(std::pow(10.0, -29487.0*x14 + 3.8010000000000002*x15*x17 - 27.029), x20)*std::pow(std::pow(10.0, -23474.0*x14 - 1.75*x15*x17 - 2.7290000000000001), 1.0 - x20);
# 220:         k[11] = 7.2000000000000002e-15;
# 221:         k[12] = 3.7e-14*std::exp(35.0*x14);
# 222:         k[13] = 1.7320508075688774e-12*x21*x22;
# 223:         k[14] = 1.3376400930597507e-9/(x23*(6.3095734448019361e-5*x23 + 1.0));
# 224:         k[15] = 1.8291653197355396e-18*std::pow(x1, 0.87790000000000001);
# 225:         k[16] = 1.43e-9;
# 226:         k[17] = 2.2561358031783838e-10*std::pow(x24, 0.2289800603272916)*std::exp(x26*(-0.0045551200270320949*x25 - 0.0003105115447124016*x26 + 0.0001073294010367247*x27 - 8.3667196046786397e-6*x28 + 2.238306228891639e-7*x29 + 0.03599837721023835));
# 227:         k[18] = 1.8500000000000001e-23*std::pow(std::max(2.73, std::min(6700.0, tgas)), 1.8);
# 228:         k[19] = 5.8099999999999997e-16*std::pow(x30, -0.66569999999999996*x17*std::log(x30));
# 229:         k[20] = 6.0e-10;
# 230:         k[21] = 4.4222953241885308e-25*std::pow(x31, 3.400824447095291)*std::exp(x33*(-9.3634588892861096e-6*std::pow(x32, 6) + 0.0004138398421504563*std::pow(x32, 5) - 0.007879026154483455*std::pow(x32, 4) + 0.084107750376341203*std::pow(x32, 3) + 2.045587822403071*x32 - 0.5416182856220388*x33 - 3.898003964650152));
# 231:         k[22] = 5.6e-11*x34*std::exp(-102124.0*x35);
# 232:         k[23] = 7.0822171322421045e-19*std::pow(x1, 2.012)*std::pow(2.1302071896000001e-5*x1 + 1.0, -3.512)*std::exp(-51790.905851142285*x35);
# 233:         k[24] = 3.7903999274394518e-18*std::pow(x1, 2.360852208681)*std::exp(x3*(0.01623316639567*x2 - 0.03365012031362999*x3 + 0.01178329782711*x4 - 0.001656194699504*x5 + 0.0001068275202678*x6 - 2.6312858092069998e-6*x7 - 0.28274430617039997));
# 234:         k[25] = 1.4643482606109061e-16*std::pow(std::max(2.73, std::min(1160.0, tgas)), 1.78186);
# 235:         k[26] = 3.3178155742407601e-14*std::pow(x24, 1.139449335841631)*std::exp(x26*(-8.0683824611800006e-8*std::pow(x25, 7) + 2.4555011970391999e-6*std::pow(x25, 6) + 0.0084644553866299998*x25 - 0.0014327641212992001*x26 + 0.00020122502847909999*x27 + 8.6639632430900003e-5*x28 - 2.5850096802639999e-5*x29 - 0.1421013521554148));
# 236:         k[27] = 7.0020735256932935e-7*x36;
# 237:         k[28] = 1.0e-8*std::pow(x1, -0.40000000000000002);
# 238:         k[29] = 1.0e-8;
# 239:         k[30] = 1.3200000000000001e-6*std::pow(std::max(617.0, x0), -0.76000000000000001);
# 240:         k[31] = 4.9999999999999996e-6*x36;
# 241:         k[32] = std::pow(1.1800000000000001e-10*std::exp(-69500.0*x14), x38)*std::pow(8.1250000000000003e-8*x22*(1.0 - x39)/x21, 1.0 - x38);
# 242:         k[33] = 6.9000000000000002e-32*std::pow(tgas, -0.40000000000000002);
# 243:         k[34] = 1.1356628756269617e-31*x41;
# 244:         k[35] = 3.8999999999999996e-30*x42;
# 245:         k[36] = 1.4195785945337021e-32*x41;
# 246:         k[37] = 4.8749999999999995e-31*x42;
# 247:         k[38] = 1.4308352583277892e-10*std::pow(std::max(2.73, std::min(7950.0, tgas)), -0.59999999999999998);
# 248:         k[39] = 8.3535906003219958e-24*std::pow(x43, 2.4900000000000002)*std::exp(21845.599999999999/x43);
# 249:         k[40] = 1.1823791726576386e-12;
# 250:         k[41] = 1.7277382714261424e-10*std::pow(std::max(2.73, x44), -0.55000000000000004);
# 251:         k[42] = 3.0151926846438625e-11*std::pow(x45, -0.32000000000000001);
# 252:         k[43] = 1.2999999999999999e-10*std::pow(std::max(2.73, std::min(400.0, tgas)), -0.64000000000000001);
# 253:         k[44] = 0.00073999999999999999*std::pow(x46, -1.5)*(1.0 + 0.062*std::exp(-145000.0*x47))*std::exp(-175000.0*x47) + 1.41e-10*std::pow(x46, -0.66000000000000003);
# 254:         k[45] = 1.3023623244766063e-6*x48*std::exp(-x49)/(x49 + 0.193);
# 255:         k[46] = 3.3019308008249855e-6*x48*(1.0 + 308.47518711624969/x34)*std::exp(-x50)/(x50 + 0.376);
# 256:         k[47] = 2.1012161411986507e-6*std::pow(x1, -0.34000000000000002)*std::exp(-x51)/(x51 + 0.072999999999999995);
# 257:         k[48] = 7.5399999999999998e-10*std::pow(x1, -0.45800000000000002) + 4.9899999999999997e-11*std::pow(x1, 0.40500000000000003);
# 258:         k[49] = (4.0000000000000001e-10*std::pow(x1, 0.0066899999999999998) + 1.0799999999999999e-11*std::pow(x1, 0.51700000000000002))*std::exp(-227.0*x35);
# 259:         k[50] = 2.038190607495647e-14*std::pow(x1, -0.21629999999999999)*std::exp(-1.2258e-6*x1) + 1.5156103761232729e-16*std::pow(x1, 0.37940000000000002)*std::exp(-8.9205999999999996e-7*x1);
# 260:         k[51] = 3.8999999999999998e-16*std::pow(x1, 0.21299999999999999);
# 261:         k[52] = 8.7882738061352424e-22*std::pow(x1, 1.96)*std::exp(-170000.0*x35);
# 262:         k[53] = 8.5799999999999996e-17*std::pow(std::max(2.73, std::min(200.0, tgas)), 0.75700000000000001);
# 263:         k[54] = 3.2499999999999998e-17*std::pow(std::max(200.0, x44), 0.96799999999999997);
# 264:         k[55] = 2.77e-19*std::pow(std::max(2000.0, x0), 1.597);
# 265:         k[56] = 5.8800000000000002e-13*std::pow(std::max(2.73, x13), 0.84799999999999998);
# 266:         k[57] = 1.4499999999999999e-13*std::max(10000.0, x0);
# 267:         k[58] = 3.3000000000000002e-9;
# 268:         k[59] = 2.1000000000000002e-9;
# 269:         k[60] = 4.4955606041870586e-11*x53*std::exp(-36879.116915736093/x52);
# 270:         k[61] = 1.3486681812561178e-10*x53;
# 271:         k[62] = 6.0455810608518555e-10*std::pow(x1, -0.63460000000000005);
# 272:         k[63] = 6.0e-9*std::exp(-50900.0*x14);
# 273:         k[64] = 3.0e-10;
# 274:         k[65] = 1.14e-9;
# 275:         k[66] = 6.2094116000000001e-9*x55 + 8.68e-10 + 3.6490561664708348e-10/std::sqrt(x54);
# 276:         k[67] = 6.6399999999999998e-10*std::exp(-11700.0*x14);
# 277:         k[68] = 1.3100000000000001e-10*std::exp(-80.0*x14);
# 278:         k[69] = 5.4599999999999998e-10*std::exp(-1943.0*x14);
# 279:         k[70] = 2.4e-10;
# 280:         k[71] = 6.6000000000000005e-11;
# 281:         k[72] = 1.02e-10*std::exp(-914.0*x56);
# 282:         k[73] = 5.3508202421495505e-6*std::pow(tgas, -2.2000000000000002)*std::exp(-165.09999999999999*x14);
# 283:         k[74] = 2.5200000000000001e-11*std::exp(-2381.0*x14);
# 284:         k[75] = 2.1999999999999999e-10;
# 285:         k[76] = 2.0399999999999999e-10*x57;
# 286:         k[77] = 1.36e-10*x57;
# 287:         k[78] = 5.01e-11;
# 288:         k[79] = 4.9800000000000004e-10*x39;
# 289:         k[80] = 3.9653775749189121e-12*std::pow(x40, -0.12);
# 290:         k[81] = 2.6659328482428137e-14*std::pow(x58, 0.75700000000000001);
# 291:         k[82] = 1.46e-12*std::exp(-9650.0*x14);
# 292:         k[83] = 8.1009819130659227e-21*std::pow(tgas, 2.7999999999999998)*std::exp(-1950.0*x14);
# 293:         k[84] = 3.5999999999999998e-16*std::pow(tgas, 1.52)*std::exp(-1740.0*x14);
# 294:         k[85] = 3.6800000000000002e-10;
# 295:         k[86] = 1.5557027645121538e-10*std::pow(x54, -0.33900000000000002)*std::exp(-0.108*x55);
# 296:         k[87] = 2.4000000000000001e-11*std::exp(-110.0*x14);
# 297:         k[88] = 2.4200000000000002e-12;
# 298:         k[89] = 2.0060141962641481e-20*std::pow(x59, 2.6200000000000001)*std::exp(-945.0/x59);
# 299:         k[90] = 1.38e-12;
# 300:         k[91] = 2.4749459212614312e-15*std::pow(tgas, 1.1399999999999999)*std::exp(-50.0*x14);
# 301:         k[92] = 6.3600000000000002e-14*tgas*std::exp(-9610.0*x14);
# 302:         k[93] = 3.1319999999999996e-10*std::exp(-8156.0*x14);
# 303:         k[94] = 3.1599999999999999e-10*std::exp(-21890.0*x14);
# 304:         k[95] = 3.2682787072746432e-10*std::pow(std::min(295.0, tgas), -0.34000000000000002);
# 305:         k[96] = 3.799136944933967e-16*std::pow(x60, 1.54)*std::exp(613.0/x60);
# 306:         k[97] = 6.3508529610858833e-12*x61*std::exp(-77700.0*x14);
# 307:         k[98] = 1.7628238824804469e-9*std::pow(tgas, 0.042000000000000003)*std::exp(-2.145922746781116e-5*tgas);
# 308:         k[99] = 7.6999999999999995e-9*std::exp(-17560.0*x14);
# 309:         k[100] = 2.4e-9;
# 310:         k[101] = (7.2733000000000004e-11*x21 + x62 + 1.0217999999999999e-9)/(0.044914000000000003*x21 - x62 + x63 + 2.6396999999999999e-6*x64);
# 311:         k[102] = 8.5144999999999999e-10/(-4.4039999999999998e-5*tgas + 0.00095666000000000002*x21 + x63 + 2.3495999999999999e-6*x64);
# 312:         k[103] = 1.0e-10*std::exp(-4640.0*x14);
# 313:         k[104] = 7.5e-10;
# 314:         k[105] = 1.2e-9;
# 315:         k[106] = 3.4999999999999998e-10;
# 316:         k[107] = 1.0000000000000001e-9*std::exp(-7080.0*x14);
# 317:         k[108] = 1.6000000000000001e-9;
# 318:         k[109] = 7.5e-10;
# 319:         k[110] = 6.9999999999999996e-10*std::exp(-10560.0*x14);
# 320:         k[111] = 2.5000000000000002e-10;
# 321:         k[112] = 2.5000000000000002e-10;
# 322:         k[113] = 4.8e-10;
# 323:         k[114] = 1.69e-9;
# 324:         k[115] = 1.5e-9;
# 325:         k[116] = 1.9428255538642216e-9*x65;
# 326:         k[117] = 8.3263952308466638e-10*x65;
# 327:         k[118] = 2.2799999999999999e-8;
# 328:         k[119] = 6.90258966293318e-8*x66 + 9.4239999999999997e-10;
# 329:         k[120] = 2.2799999999999999e-8;
# 330:         k[121] = 4.1551773299893819e-8*x66 + 5.673e-10;
# 331:         k[122] = 1.01e-9;
# 332:         k[123] = 6.3999999999999996e-10;
# 333:         k[124] = 2.55e-8;
# 334:         k[125] = 7.7276803148672875e-8*x66 + 1.0726e-9;
# 335:         k[126] = 1.8e-9;
# 336:         k[127] = 5.0300000000000002e-9;
# 337:         k[128] = 1.522889046096939e-8*x66 + 2.1137659999999997e-10;
# 338:         k[129] = 2.4e-10;
# 339:         k[130] = 9.9999999999999994e-12;
# 340:         k[131] = 3.4200000000000001e-10;
# 341:         k[132] = 4.5299999999999999e-10;
# 342:         k[133] = 9.0999999999999996e-10;
# 343:         k[134] = 5.2000000000000001e-11;
# 344:         k[135] = 5.2000000000000001e-11;
# 345:         k[136] = 2.4699999999999999e-9;
# 346:         k[137] = 3.3766779690000001e-9*x55 + 7.9052441707634545e-10*x66 + 1.8805500000000001e-9;
# 347:         k[138] = 1.4499999999999999e-10;
# 348:         k[139] = 1.9438230848e-10*x55 + 4.5507437342807608e-11*x66 + 1.08256e-10;
# 349:         k[140] = 1.0000000000000001e-9;
# 350:         k[141] = 1.2299999999999999e-8;
# 351:         k[142] = 6.9569434392000005e-7*x55 + 7.5577829142171064e-9*x66 + 8.3400000000000002e-10;
# 352:         k[143] = 3.2999999999999998e-8;
# 353:         k[144] = 9.733146825907767e-8*x66 + 2.1947999999999999e-9;
# 354:         k[145] = x68;
# 355:         k[146] = x72;
# 356:         k[147] = x68;
# 357:         k[148] = x72;
# 358:         k[149] = x73;
# 359:         k[150] = x74;
# 360:         k[151] = x73;
# 361:         k[152] = x74;
# 362:         k[153] = 1.6000000000000001e-9;
# 363:         k[154] = 3.7499999999999998e-8;
# 364:         k[155] = 1.1352943524561152e-7*x66 + 1.55e-9;
# 365:         k[156] = 2.1999999999999998e-8;
# 366:         k[157] = 6.130589503263022e-8*x66 + 8.37e-10;
# 367:         k[158] = 4.1999999999999999e-8;
# 368:         k[159] = 1.2730571616977901e-7*x66 + 1.767e-9;
# 369:         k[160] = 7.5599999999999995e-9;
# 370:         k[161] = x75;
# 371:         k[162] = 7.5599999999999995e-9;
# 372:         k[163] = x75;
# 373:         k[164] = 7.5599999999999995e-9;
# 374:         k[165] = x75;
# 375:         k[166] = 2.0000000000000001e-9;
# 376:         k[167] = 3.3000000000000002e-11;
# 377:         k[168] = 1.0999999999999999e-9;
# 378:         k[169] = 2.4248711305964283e-8*x76;
# 379:         k[170] = 2.4248711305964286e-15*x76;
# 380:         k[171] = 7.5e-10;
# 381:         k[172] = x77;
# 382:         k[173] = x77;
# 383:         k[174] = x77;
# 384:         k[175] = 4.5427507615910105e-7*x78;
# 385:         k[176] = 8.4642706498020525e-7*x78;
# 386:         k[177] = 1.2124355652982142e-6*x76;
# 387:         k[178] = 4.9022193004806484e-6*x79;
# 388:         k[179] = 2.3530652642307112e-6*x79;
# 389:         k[180] = 1.2347464863085633e-5*x79;
# 390:         k[181] = 1.3423393758658801e-6*x76;
# 391:         k[182] = 3.3774990747593113e-6*x76;
# 392:         k[183] = 3.4641016151377547e-6*x76;
# 393:         k[184] = 9.7355109978586414e-8*std::pow(tgas, -0.47999999999999998);
# 394:         k[185] = 6.7549981495186216e-7*x76;
# 395:         k[186] = 1.4895636945092346e-6*x76;
# 396:         k[187] = 5.2827549630850758e-6*x76;
# 397:         k[188] = 4.4686910835277041e-6*x76;
# 398:         k[189] = 9.6994845223857133e-8*x76;
# 399:         k[190] = 1.8706148721743877e-6*x76;
# 400:         k[191] = 1.0426945861564643e-5*x76;
# 401:         k[192] = 1.0568649366703788e-5*std::pow(tgas, -0.69999999999999996);
# 402:         k[193] = 6.3350403285625223e-6*std::pow(tgas, -0.55000000000000004);
# 403:         k[194] = 1.0623477076014166e-5*x80;
# 404:         k[195] = 9.2378061530557967e-7*x80;
# 405:         k[196] = 3.3000000000000003e-5*x14;
# 406:         k[197] = 1.0000000000000001e-9;
# 407:         k[198] = 1.0e-10;
# 408:         k[199] = 5.0000000000000003e-10;
# 409:         k[200] = 1.0e-13;
# 410:         k[201] = 5.0000000000000003e-10;
# 411:         k[202] = 5.0000000000000003e-10;
# 412:         k[203] = 6.9999999999999996e-10;
# 413:         k[204] = 6.9999999999999996e-10;
# 414:         k[205] = 5.0000000000000003e-10;
# 415:         k[206] = 6.3999999999999996e-10*std::exp(-21300.0*x14);
# 416:         k[207] = 1.7320508075688772e-12*x22*x61;
# 417:         k[208] = 9.9999999999999998e-17;
# 418:         k[209] = 2.2499999999999999e-15;
# 419:         k[210] = 1.0000000000000001e-17;
# 420:         k[211] = 1.0000000000000001e-17;
# 421:         k[212] = 5.9223497313474423e-19*std::pow(tgas, 0.34999999999999998)*std::exp(-161.30000000000001*x14);
# 422:         k[213] = 9.9999999999999998e-20;
# 423:         k[214] = 4.7044457564984403e-18*std::pow(x58, 0.33000000000000002)*std::exp(-1629.0*x81);
# 424:         k[215] = 4.4600000000000005e-16*x76*std::exp(-4.9299999999999997*std::pow(tgas, -0.66669999999999996));
# 425:         k[216] = 3.3211433913761482e-13*std::pow(tgas, -1.3)*std::exp(-23.0*x14);
# 426:         k[217] = 2.5000000000000002e-18;
# 427:         k[218] = 7.3875058242066447e-18*std::pow(x58, -0.14999999999999999)*std::exp(-68.0*x81);
# 428:         k[219] = 1.4999999999999999e-15;
# 429:         k[220] = 8.648509591313017e-18*std::pow(tgas, -0.38);
# 430:         k[221] = 5.9750906373648399e-24*std::pow(tgas, 1.5800000000000001);
# 431:         k[222] = 4.4828963110189506e-5*std::pow(tgas, -5.2199999999999998)*std::exp(-90.0*x14);
# 432:         k[223] = 2.9999999999999998e-18*x19*x21/((1.0 + 10000.0*std::exp(-600.0/(tdust + 9.9999999999999993e-41)))*(0.002*tgas + 7.9999999999999996e-6*x82 + 0.040000000000000001*std::sqrt(tdust + tgas) + 1.0)*nden[0]);
# 433:         k[224] = 7.0999999999999998e-7*x83;
# 434:         k[225] = 1.0999999999999999e-9*std::exp(-1.8999999999999999*av);
# 435:         k[226] = 5.6e-11*(0.96499999999999997/std::pow(37400.0*x84 + 1, 2) + 0.035000000000000003*std::exp(std::max(-250.0, -0.00084999999999999995*x85))/x85)*std::exp(-3.7400000000000002*av);
# 436:         k[227] = 4.9000000000000003e-13*x86;
# 437:         k[228] = 4.9000000000000003e-13*x87;
# 438:         k[229] = 3.1000000000000002e-10*std::exp(-3.0*av);
# 439:         k[230] = 2.3999999999999998e-7*std::exp(-0.90000000000000002*av);
# 440:         k[231] = 8.6999999999999999e-10*std::exp(-1.2*av);
# 441:         k[232] = 7.7000000000000003e-10*x88;
# 442:         k[233] = 2.5999999999999998e-10*std::exp(-2.5*av);
# 443:         k[234] = 7.1000000000000003e-10*x89;
# 444:         k[235] = 5.9000000000000003e-10*x87;
# 445:         k[236] = 4.6000000000000001e-10*x89;
# 446:         k[237] = x90;
# 447:         k[238] = x90;
# 448:         k[239] = 1.5e-10*std::exp(-2.1000000000000001*av);
# 449:         k[240] = 2.3999999999999998e-7*x83;
# 450:         k[241] = 3.7000000000000001e-10*x89;
# 451:         k[242] = 1.6e-12*std::exp(-3.1000000000000001*av);
# 452:         k[243] = 9.9999999999999998e-13*x86;
# 453:         k[244] = 6.0e-10*x89;
# 454:         k[245] = 3.1999999999999999e-11*std::exp(-3.8999999999999999*av);
# 455:         k[246] = x92;
# 456:         k[247] = x92;
# 457:         k[248] = x92;
# 458:         k[249] = 1.5e-10*x91;
# 459:         k[250] = x93;
# 460:         k[251] = x93;
# 461:         k[252] = 7.5e-12*x91;
# 462:         k[253] = x93;
# 463:         k[254] = 5.6e-11*std::exp(-3.7000000000000002*av);
# 464:         k[255] = 6.9999999999999996e-10*x86;
# 465:         k[256] = 2.0000000000000001e-10*std::exp(-3.5299999999999998*av);
# 466:         k[257] = 0.46000000000000002*crate;
# 467:         k[258] = 0.5*crate;
# 468:         k[259] = 2.7999999999999998*crate;
# 469:         k[260] = 5.0*crate;
# 470:         k[261] = 3.0*crate;
# 471:         k[262] = 237.0*crate;
# 472:         k[263] = 0.10000000000000001*crate;
# 473:         k[264] = 0.00029999999999999997*crate;
# 474:         k[265] = x94;
# 475:         k[266] = 1020.0*crate;
# 476:         k[267] = 730.0*crate;
# 477:         k[268] = 750.0*crate;
# 478:         k[269] = 117.0*crate;
# 479:         k[270] = 510.0*crate;
# 480:         k[271] = 500.0*crate;
# 481:         k[272] = 970.0*crate;
# 482:         k[273] = 421.0*crate;
# 483:         k[274] = 1170.0*crate;
# 484:         k[275] = x94;
# 485:         k[276] = 4.9633948909666331e-27*x95*std::pow(std::min(5000.0, tgas), -1.6000000000000001);
# 486:         k[277] = 1.3956214160944883e-30*x95*std::pow(x96, -0.64000000000000001)*std::exp(5255.0/x96);
# 487:         k[278] = 2.6249085452559345e-21*x97;
# 488:         k[279] = 9.1190004656618497e-22*x98;
# 489:         k[280] = x99;
# 490:         k[281] = x100;
# 491:         k[282] = x99;
# 492:         k[283] = x100;
# 493:         k[284] = 1.2990000000000001e-29*x101;
# 494:         k[285] = 2.3040000000000002e-26*x95/x82;
# 495:         k[286] = 2.7600000000000001e-31*x101;
# 496:
# 497:         // PREPROCESS_END
# 498:
# 499:         // Compute derivatives for each species
# 500:         // PREPROCESS_ODE
# 501:
# 502:         const double cse0 = 1.0/tgas;
# 503:         const double cse1 = 3.3000000000000003e-5*cse0*nden[1]*nden[17];
# 504:         const double cse2 = 6.3999999999999996e-10*nden[6];
# 505:         const double cse3 = cse2*nden[32];
# 506:         const double cse4 = std::min(100000000.0, tgas);
# 507:         const double cse5 = std::max(2.73, cse4);
# 508:         const double cse6 = nden[8]/std::sqrt(cse5);
# 509:         const double cse7 = 4.9999999999999996e-6*cse6*nden[7];
# 510:         const double cse8 = std::exp(-2.2999999999999998*av);
# 511:         const double cse9 = 4.9000000000000003e-13*nden[26];
# 512:         const double cse10 = cse8*cse9;
# 513:         const double cse11 = 7.5e-10*nden[14]*nden[28];
# 514:         const double cse12 = std::max(10.0, tgas);
# 515:         const double cse13 = std::pow(cse12, -0.5);
# 516:         const double cse14 = nden[9]*nden[24];
# 517:         const double cse15 = cse14*(1.522889046096939e-8*cse13 + 2.1137659999999997e-10);
# 518:         const double cse16 = 2.4e-9*nden[7]*nden[10];
# 519:         const double cse17 = std::exp(-1.7*av);
# 520:         const double cse18 = 4.6000000000000001e-10*cse17*nden[28];
# 521:         const double cse19 = 7.5e-10*nden[0];
# 522:         const double cse20 = cse19*nden[27];
# 523:         const double cse21 = -cse20;
# 524:         const double cse22 = std::sqrt(1.0/std::min(150.0, tgas));
# 525:         const double cse23 = 1.1234460077595736e-8*cse22 + 5.9830000000000009e-10;
# 526:         const double cse24 = nden[4]*nden[21];
# 527:         const double cse25 = cse23*cse24;
# 528:         const double cse26 = std::max(150.0, tgas);
# 529:         const double cse27 = std::pow(cse26, -0.5);
# 530:         const double cse28 = 1.0/cse26;
# 531:         const double cse29 = 2.2789433385850798e-9*cse27 + 5.4679360630822505e-8*cse28 + 9.6500000000000008e-10;
# 532:         const double cse30 = cse24*cse29;
# 533:         const double cse31 = nden[6]*nden[9];
# 534:         const double cse32 = 1.0e-10*cse31*std::exp(-4640.0*cse0);
# 535:         const double cse33 = nden[4]*nden[6];
# 536:         const double cse34 = 3.7e-14*cse33*std::exp(35.0*cse0);
# 537:         const double cse35 = 1.0999999999999999e-9*std::exp(-1.8999999999999999*av)*nden[7];
# 538:         const double cse36 = nden[1]*nden[7];
# 539:         const double cse37 = crate*nden[6];
# 540:         const double cse38 = 1.6000000000000001e-9*nden[6]*nden[28];
# 541:         const double cse39 = std::pow(nden[0], 3);
# 542:         const double cse40 = std::min(300.0, tgas);
# 543:         const double cse41 = std::pow(std::max(2.73, cse40), -0.38);
# 544:         const double cse42 = cse39*cse41;
# 545:         const double cse43 = 1.0/std::max(300.0, cse4);
# 546:         const double cse44 = cse39*cse43;
# 547:         const double cse45 = nden[0]*nden[8];
# 548:         const double cse46 = 1.43e-9*cse45;
# 549:         const double cse47 = std::log(0.0001*tgas);
# 550:         const double cse48 = M_LN10;
# 551:         const double cse49 = 1.0/cse48;
# 552:         const double cse50 = 2*nden[6];
# 553:         const double cse51 = 2*nden[21];
# 554:         const double cse52 = nden[0] + nden[2] + nden[8] + nden[16] + nden[17] + nden[18] + nden[20] + nden[23] + nden[27] + nden[31];
# 555:         const double cse53 = cse50 + cse51 + cse52 + 2*nden[7] + 2*nden[24] + 3*nden[26] + 2*nden[28] + 3*nden[30] + 2*nden[32] + 3*nden[33];
# 556:         const double cse54 = 1.0/(cse53/(std::pow(10.0, 1.6200000000000001*std::pow(cse47, 2)/std::pow(cse48, 2) - 1.3*cse47*cse49 + 4.8449999999999998) + 9.9999999999999993e-41) + 1.0);
# 557:         const double cse55 = std::sqrt(tgas);
# 558:         const double cse56 = std::exp(-52000.0*cse0);
# 559:         const double cse57 = std::exp(-6000.0*cse0);
# 560:         const double cse58 = std::pow(1.1800000000000001e-10*std::exp(-69500.0*cse0), cse54)*std::pow(8.1250000000000003e-8*cse56*(1.0 - cse57)/cse55, 1.0 - cse54)*std::pow(nden[6], 2);
# 561:         const double cse59 = cse36*std::pow(std::max(617.0, cse4), -0.76000000000000001);
# 562:         const double cse60 = std::sqrt(tgas);
# 563:         const double cse61 = 1.0/cse60;
# 564:         const double cse62 = cse61*nden[1];
# 565:         const double cse63 = 1.2124355652982142e-6*cse62*nden[27];
# 566:         const double cse64 = cse62*nden[33];
# 567:         const double cse65 = std::pow(tgas, -0.52000000000000002)*nden[1]*nden[26];
# 568:         const double cse66 = cse62*nden[32];
# 569:         const double cse67 = 9.7355109978586414e-8*std::pow(tgas, -0.47999999999999998)*nden[1]*nden[31];
# 570:         const double cse68 = 1.12e-10*nden[6];
# 571:         const double cse69 = std::pow(nden[6], 0.66666666666666663);
# 572:         const double cse70 = std::sqrt(37400.000000000015*cse69 + 1);
# 573:         const double cse71 = (0.96499999999999997/std::pow(37400.0*cse69 + 1, 2) + 0.035000000000000003*std::exp(std::max(-250.0, -0.00084999999999999995*cse70))/cse70)*std::exp(-3.7400000000000002*av);
# 574:         const double cse72 = std::pow(tgas, -0.59999999999999998);
# 575:         const double cse73 = cse72*nden[1]*nden[28];
# 576:         const double cse74 = cse62*nden[30];
# 577:         const double cse75 = cse6*nden[2];
# 578:         const double cse76 = nden[14]*nden[21];
# 579:         const double cse77 = cse76*std::exp(-270.0*cse0);
# 580:         const double cse78 = 7.6999999999999995e-9*std::exp(-17560.0*cse0)*nden[0]*nden[26];
# 581:         const double cse79 = 1.7793594306049821e-5*std::max(6700.0, cse4);
# 582:         const double cse80 = nden[0]*nden[2];
# 583:         const double cse81 = 5.8099999999999997e-16*std::pow(cse79, -0.66569999999999996*cse49*std::log(cse79))*cse80;
# 584:         const double cse82 = 1.8500000000000001e-23*cse80*std::pow(std::max(2.73, std::min(6700.0, tgas)), 1.8);
# 585:         const double cse83 = std::pow(nden[0], 2);
# 586:         const double cse84 = cse83*nden[6];
# 587:         const double cse85 = cse41*cse84;
# 588:         const double cse86 = cse43*cse84;
# 589:         const double cse87 = cse83*std::pow(tgas, -0.40000000000000002)*nden[3];
# 590:         const double cse88 = 6.9999999999999996e-10*std::exp(-10560.0*cse0)*nden[0]*nden[30];
# 591:         const double cse89 = std::log(tgas);
# 592:         const double cse90 = 1.0/(cse53/(std::pow(10.0, 5.2041483199999998 - 6.247416000000001e-5*tgas) + 9.9999999999999993e-41) + 1.0);
# 593:         const double cse91 = std::pow(std::pow(10.0, -29487.0*cse0 + 3.8010000000000002*cse49*cse89 - 27.029), cse90)*std::pow(std::pow(10.0, -23474.0*cse0 - 1.75*cse49*cse89 - 2.7290000000000001), 1.0 - cse90)*nden[3];
# 594:         const double cse92 = 1.7628238824804469e-9*std::pow(tgas, 0.042000000000000003)*std::exp(-2.145922746781116e-5*tgas)*nden[6]*nden[7];
# 595:         const double cse93 = nden[2]*nden[6];
# 596:         const double cse94 = cse56*cse60*cse93;
# 597:         const double cse95 = std::sqrt(cse5);
# 598:         const double cse96 = 1.0/cse5;
# 599:         const double cse97 = cse95*std::exp(-102124.0*cse96)*nden[1];
# 600:         const double cse98 = cse33*cse55*cse56;
# 601:         const double cse99 = nden[0]*nden[9];
# 602:         const double cse100 = 4.4600000000000005e-16*cse61*cse99*std::exp(-4.9299999999999997*std::pow(tgas, -0.66669999999999996));
# 603:         const double cse101 = std::max(1160.0, cse4);
# 604:         const double cse102 = std::log(8.6173430000000006e-5*cse101);
# 605:         const double cse103 = std::pow(cse102, 2);
# 606:         const double cse104 = std::pow(cse102, 3);
# 607:         const double cse105 = std::pow(cse102, 4);
# 608:         const double cse106 = std::pow(cse102, 5);
# 609:         const double cse107 = std::pow(cse102, 6);
# 610:         const double cse108 = std::pow(cse102, 7);
# 611:         const double cse109 = 2.2561358031783838e-10*std::pow(cse101, 0.2289800603272916)*cse45*std::exp(0.03599837721023835*cse103 - 0.0045551200270320949*cse104 - 0.0003105115447124016*cse105 + 0.0001073294010367247*cse106 - 8.3667196046786397e-6*cse107 + 2.238306228891639e-7*cse108);
# 612:         const double cse110 = std::pow(cse5, 2.012)*std::pow(2.1302071896000001e-5*cse5 + 1.0, -3.512)*std::exp(-51790.905851142285*cse96)*nden[0]*nden[6];
# 613:         const double cse111 = std::pow(tgas, 2);
# 614:         const double cse112 = cse53*cse55*nden[0]/((1.0 + 10000.0*std::exp(-600.0/(tdust + 9.9999999999999993e-41)))*(7.9999999999999996e-6*cse111 + 0.002*tgas + 0.040000000000000001*std::sqrt(tdust + tgas) + 1.0));
# 615:         const double cse113 = std::exp(-2.7999999999999998*av);
# 616:         const double cse114 = ((av < 15) ? (
# 617:            std::exp(0.016500000000000001*std::pow(av, 2) - 2.5499999999999998*av)
# 618:         )
# 619:         : (
# 620:            cse113
# 621:         ));
# 622:         const double cse115 = cse114*nden[32];
# 623:         const double cse116 = 1.5e-9*nden[7]*nden[14];
# 624:         const double cse117 = 1.69e-9*nden[6]*nden[13];
# 625:         const double cse118 = nden[4]*nden[24];
# 626:         const double cse119 = 2.2906988549538973e-8*cse13 + 3.1794839999999998e-10;
# 627:         const double cse120 = cse118*cse119;
# 628:         const double cse121 = 7.5599999999999995e-9*cse118 + cse120;
# 629:         const double cse122 = 1.5e-10*cse115 + cse116 + cse117 + cse121;
# 630:         const double cse123 = cse114*nden[33];
# 631:         const double cse124 = 1.01e-9*nden[6]*nden[31];
# 632:         const double cse125 = std::pow(tgas, -0.156)*std::exp(-1.4099999999999999*cse0)*nden[14]*nden[26];
# 633:         const double cse126 = nden[2]*nden[24];
# 634:         const double cse127 = cse126*(1.2730571616977901e-7*cse13 + 1.767e-9) + 4.1999999999999999e-8*cse126;
# 635:         const double cse128 = 7.5e-12*cse123 + cse124 + 8.3263952308466638e-10*cse125 + cse127;
# 636:         const double cse129 = std::exp(-0.5*av);
# 637:         const double cse130 = 7.0999999999999998e-7*cse129*nden[8];
# 638:         const double cse131 = 1.4643482606109061e-16*cse45*std::pow(std::max(2.73, std::min(1160.0, tgas)), 1.78186);
# 639:         const double cse132 = 3.9837168574084182e-6*cse61;
# 640:         const double cse133 = cse132*nden[4]*nden[8];
# 641:         const double cse134 = nden[0]*nden[1];
# 642:         const double cse135 = -1.8291653197355396e-18*cse134*std::pow(cse5, 0.87790000000000001);
# 643:         const double cse136 = 3.3178155742407601e-14*std::pow(cse101, 1.139449335841631)*cse45*std::exp(-8.0683824611800006e-8*std::pow(cse102, 9) + 2.4555011970391999e-6*std::pow(cse102, 8) - 0.1421013521554148*cse103 + 0.0084644553866299998*cse104 - 0.0014327641212992001*cse105 + 0.00020122502847909999*cse106 + 8.6639632430900003e-5*cse107 - 2.5850096802639999e-5*cse108);
# 644:         const double cse137 = std::log(8.6173430000000006e-5*cse5);
# 645:         const double cse138 = std::pow(cse137, 2);
# 646:         const double cse139 = std::pow(cse137, 3);
# 647:         const double cse140 = std::pow(cse137, 4);
# 648:         const double cse141 = std::pow(cse137, 5);
# 649:         const double cse142 = std::pow(cse137, 6);
# 650:         const double cse143 = std::pow(cse137, 7);
# 651:         const double cse144 = std::pow(cse137, 8);
# 652:         const double cse145 = 3.7903999274394518e-18*std::pow(cse5, 2.360852208681)*std::exp(-0.28274430617039997*cse138 + 0.01623316639567*cse139 - 0.03365012031362999*cse140 + 0.01178329782711*cse141 - 0.001656194699504*cse142 + 0.0001068275202678*cse143 - 2.6312858092069998e-6*cse144)*nden[1]*nden[8];
# 653:         const double cse146 = cse130 + cse131 + cse133 + cse135 + cse136 + cse145;
# 654:         const double cse147 = 7.1000000000000003e-10*cse17*nden[21];
# 655:         const double cse148 = 5.01e-11*cse76;
# 656:         const double cse149 = cse147 + cse148;
# 657:         const double cse150 = 1.2e-9*nden[6]*nden[27];
# 658:         const double cse151 = std::pow(tgas, 0.16669999999999999);
# 659:         const double cse152 = std::pow(tgas, 1.5);
# 660:         const double cse153 = nden[10]*nden[26];
# 661:         const double cse154 = 8.5144999999999999e-10*cse153/(cse151 + 2.3495999999999999e-6*cse152 + 0.00095666000000000002*cse55 - 4.4039999999999998e-5*tgas);
# 662:         const double cse155 = 1.0000000000000001e-9*std::exp(-7080.0*cse0)*nden[0]*nden[28];
# 663:         const double cse156 = cse17*nden[30];
# 664:         const double cse157 = 2.0548002110835724e-8*cse22 + 1.0943e-9;
# 665:         const double cse158 = nden[2]*nden[21];
# 666:         const double cse159 = 4.1682227902618297e-9*cse27 + 1.0000940075e-7*cse28 + 1.765e-9;
# 667:         const double cse160 = 1.0000000000000001e-9*cse156 + cse157*cse158 + cse158*cse159;
# 668:         const double cse161 = cse150 + cse154 - cse155 + cse160;
# 669:         const double cse162 = 3.4999999999999998e-10*nden[14]*nden[27];
# 670:         const double cse163 = cse19*nden[29];
# 671:         const double cse164 = -cse163;
# 672:         const double cse165 = nden[9]*nden[16];
# 673:         const double cse166 = cse165*(4.1551773299893819e-8*cse13 + 5.673e-10) + 2.2799999999999999e-8*cse165;
# 674:         const double cse167 = cse162 + cse164 + cse166;
# 675:         const double cse168 = 6.0e-10*nden[0]*nden[7];
# 676:         const double cse169 = cse2*std::exp(-21300.0*cse0)*nden[2];
# 677:         const double cse170 = std::max(3480.0, cse4);
# 678:         const double cse171 = std::log(8.6173430000000006e-5*cse170);
# 679:         const double cse172 = 4.4222953241885308e-25*std::pow(cse170, 3.400824447095291)*cse93*std::exp(-9.3634588892861096e-6*std::pow(cse171, 8) + 0.0004138398421504563*std::pow(cse171, 7) - 0.007879026154483455*std::pow(cse171, 6) + 0.084107750376341203*std::pow(cse171, 5) - 0.5416182856220388*std::pow(cse171, 4) + 2.045587822403071*std::pow(cse171, 3) - 3.898003964650152*std::pow(cse171, 2));
# 680:         const double cse173 = -cse168 + cse169 + cse172;
# 681:         const double cse174 = 730.0*crate*nden[20];
# 682:         const double cse175 = 2.4e-10*nden[10]*nden[20];
# 683:         const double cse176 = 8.6999999999999999e-10*std::exp(-1.2*av)*nden[20];
# 684:         const double cse177 = 1.0e-13*nden[0]*nden[35];
# 685:         const double cse178 = 1.0000000000000001e-17*nden[10];
# 686:         const double cse179 = cse178*nden[0];
# 687:         const double cse180 = 2.1999999999999999e-10*nden[0]*nden[21];
# 688:         const double cse181 = 5.4599999999999998e-10*std::exp(-1943.0*cse0)*nden[6]*nden[20];
# 689:         const double cse182 = nden[2]*nden[20];
# 690:         const double cse183 = cse182*(9.733146825907767e-8*cse13 + 2.1947999999999999e-9) + 3.2999999999999998e-8*cse182;
# 691:         const double cse184 = cse174 + cse175 + cse176 - cse177 - cse179 - cse180 + cse181 + cse183;
# 692:         const double cse185 = 970.0*crate*nden[24];
# 693:         const double cse186 = 6.0e-10*cse17*nden[24];
# 694:         const double cse187 = nden[0]*nden[16];
# 695:         const double cse188 = 4.4828963110189506e-5*cse187*std::pow(tgas, -5.2199999999999998)*std::exp(-90.0*cse0);
# 696:         const double cse189 = cse52 + nden[1] + nden[3] + nden[4] + nden[5] + nden[6] + nden[7] + nden[9] + nden[10] + nden[11] + nden[12] + nden[13] + nden[14] + nden[15] + nden[19] + nden[21] + nden[22] + nden[24] + nden[25] + nden[26] + nden[28] + nden[29] + nden[30] + nden[32] + nden[33] + nden[34] + nden[35] + nden[36];
# 697:         const double cse190 = 2.3040000000000002e-26*cse187*cse189/cse111;
# 698:         const double cse191 = cse185 + cse186 - cse188 - cse190;
# 699:         const double cse192 = crate*nden[23];
# 700:         const double cse193 = std::pow(tgas, -0.64000000000000001);
# 701:         const double cse194 = cse193*nden[1]*nden[18];
# 702:         const double cse195 = nden[14]*nden[20];
# 703:         const double cse196 = std::max(2000.0, tgas);
# 704:         const double cse197 = 1.0/cse196;
# 705:         const double cse198 = 6.6000000000000005e-11*cse195 + 1.02e-10*cse195*std::exp(-914.0*cse197);
# 706:         const double cse199 = nden[10]*nden[16];
# 707:         const double cse200 = 1.0/cse12;
# 708:         const double cse201 = 1.5557027645121538e-10*std::pow(cse12, -0.33900000000000002)*cse199*std::exp(-0.108*cse200) + 3.6800000000000002e-10*cse199 - 6.3508529610858833e-12*cse60*std::exp(-77700.0*cse0)*nden[0]*nden[19];
# 709:         const double cse202 = 421.0*cse192 + 1.0623477076014166e-5*cse194 + cse198 + cse201;
# 710:         const double cse203 = 510.0*crate*nden[16];
# 711:         const double cse204 = 3.7000000000000001e-10*cse17*nden[16];
# 712:         const double cse205 = 6.9999999999999996e-10*nden[36];
# 713:         const double cse206 = cse205*nden[0];
# 714:         const double cse207 = 6.0e-9*cse187*std::exp(-50900.0*cse0);
# 715:         const double cse208 = nden[0]*nden[14];
# 716:         const double cse209 = 8.648509591313017e-18*cse208*std::pow(tgas, -0.38);
# 717:         const double cse210 = 3.5999999999999998e-16*std::pow(tgas, 1.52)*std::exp(-1740.0*cse0)*nden[6]*nden[16];
# 718:         const double cse211 = 6.3600000000000002e-14*tgas*std::exp(-9610.0*cse0)*nden[0]*nden[24];
# 719:         const double cse212 = cse0*cse189;
# 720:         const double cse213 = 1.2990000000000001e-29*cse208*cse212;
# 721:         const double cse214 = nden[2]*nden[16];
# 722:         const double cse215 = cse214*(1.1352943524561152e-7*cse13 + 1.55e-9) + 3.7499999999999998e-8*cse214;
# 723:         const double cse216 = nden[4]*nden[16];
# 724:         const double cse217 = cse216*(6.130589503263022e-8*cse13 + 8.37e-10) + 2.1999999999999998e-8*cse216;
# 725:         const double cse218 = nden[14]*nden[16];
# 726:         const double cse219 = 3.8e-12*cse218;
# 727:         const double cse220 = 2.4000000000000001e-11*cse218*std::exp(-110.0*cse0);
# 728:         const double cse221 = 3.1319999999999996e-10*std::exp(-8156.0*cse0)*nden[0]*nden[25];
# 729:         const double cse222 = std::max(200.0, std::min(350.0, tgas));
# 730:         const double cse223 = 2.0060141962641481e-20*cse218*std::pow(cse222, 2.6200000000000001)*std::exp(-945.0/cse222);
# 731:         const double cse224 = cse219 + cse220 - cse221 + cse223;
# 732:         const double cse225 = cse203 + cse204 - cse206 + cse207 - cse209 + cse210 - cse211 - cse213 + cse215 + cse217 + cse224;
# 733:         const double cse226 = 2.0000000000000001e-9*nden[2]*nden[25];
# ...
# 2695:         J[14][29] = -cse561 - cse805;
# 2696:         J[14][30] = cse835;
# 2697:         J[14][31] = -cse441 + cse586 - cse805;
# 2698:         J[14][32] = 5.9582547780369377e-6*cse2*nden[1] - cse800 - cse805;
# 2699:         J[14][33] = 9.6994845223857133e-8*cse2*nden[1] - cse805;
# 2700:         J[14][34] = 2.1137298733407577e-5*cse456*nden[1] - cse712 - cse822;
# 2701:         J[14][35] = cse835;
# 2702:         J[14][36] = -cse447 + cse572 - cse805;
# 2703:         J[15][0] = -cse134;
# 2704:         J[15][1] = cse793;
# 2705:         J[15][2] = cse226;
# 2706:         J[15][11] = cse333;
# 2707:         J[15][15] = -cse795;
# 2708:         J[16][0] = cse111 + cse145 - cse61 - cse65 + cse806 + cse836;
# 2709:         J[16][1] = cse836 + cse837*nden[18] + cse838*nden[33] + cse839*nden[32];
# 2710:         J[16][2] = -cse235 - cse840;
# 2711:         J[16][3] = cse836;
# 2712:         J[16][4] = cse249*nden[24] - cse254 - cse840 + 7.5599999999999995e-9*nden[24];
# 2713:         J[16][5] = cse836;
# 2714:         J[16][6] = -cse287 + cse291 + cse836 + cse841*nden[25];
# 2715:         J[16][7] = cse836;
# 2716:         J[16][8] = -cse524 + cse525 + cse836;
# 2717:         J[16][9] = -cse319 - cse840;
# 2718:         J[16][10] = -cse331 - cse840;
# 2719:         J[16][11] = cse836;
# 2720:         J[16][12] = cse836;
# 2721:         J[16][13] = cse836;
# 2722:         J[16][14] = -cse357 - cse359 - cse362 + cse542 + cse772 + cse817 + cse823 + cse836;
# 2723:         J[16][15] = cse836;
# 2724:         J[16][16] = -cse370 - cse382 - cse548 - cse656 - cse840 - 9.899783685045725e-15*cse842 - cse843;
# 2725:         J[16][17] = cse836;
# 2726:         J[16][18] = cse836 + cse837*nden[1];
# 2727:         J[16][19] = cse385 + cse836;
# 2728:         J[16][20] = cse783 + cse836;
# 2729:         J[16][21] = cse828 + cse836;
# 2730:         J[16][22] = cse836;
# 2731:         J[16][23] = cse836;
# 2732:         J[16][24] = cse409 + cse836 + cse844;
# 2733:         J[16][25] = cse836 + cse841*nden[6] + cse846;
# 2734:         J[16][26] = -cse671 - cse840;
# 2735:         J[16][27] = cse836;
# 2736:         J[16][28] = cse836 + cse847;
# 2737:         J[16][29] = cse836;
# 2738:         J[16][30] = cse836;
# 2739:         J[16][31] = cse836;
# 2740:         J[16][32] = cse587 + cse836 + cse839*nden[1];
# 2741:         J[16][33] = cse588 + cse836 + cse838*nden[1];
# 2742:         J[16][34] = cse836;
# 2743:         J[16][35] = cse836;
# 2744:         J[16][36] = cse435 + cse836;
# 2745:         J[17][1] = -cse175;
# 2746:         J[17][6] = -cse848;
# 2747:         J[17][9] = 1.8e-9*nden[24];
# 2748:         J[17][14] = cse849;
# 2749:         J[17][17] = -cse383 - cse851;
# 2750:         J[17][19] = cse658 - cse852 + 1.4499999999999999e-10*nden[26];
# 2751:         J[17][24] = 1.8e-9*nden[9];
# 2752:         J[17][26] = cse672 + 1.4499999999999999e-10*nden[19];
# 2753:         J[17][30] = cse853;
# 2754:         J[18][1] = -cse460;
# 2755:         J[18][6] = cse848;
# 2756:         J[18][9] = cse315 + 5.0300000000000002e-9*nden[24];
# 2757:         J[18][10] = -cse754 - cse854;
# 2758:         J[18][14] = cse815 + cse849;
# 2759:         J[18][17] = cse851;
# 2760:         J[18][18] = -cse549 - cse857;
# 2761:         J[18][19] = cse660 + cse852 + 2.4699999999999999e-9*nden[26];
# 2762:         J[18][20] = cse552;
# 2763:         J[18][23] = cse555;
# 2764:         J[18][24] = cse404 - cse858 + 5.0300000000000002e-9*nden[9];
# 2765:         J[18][25] = cse845;
# 2766:         J[18][26] = cse673 + 2.4699999999999999e-9*nden[19];
# 2767:         J[18][28] = cse859;
# 2768:         J[18][30] = cse853;
# 2769:         J[18][33] = cse678;
# 2770:         J[19][0] = cse125 + cse719;
# 2771:         J[19][1] = cse178 + cse718;
# 2772:         J[19][2] = cse718;
# 2773:         J[19][3] = cse718;
# 2774:         J[19][4] = -cse593 + cse718;
# 2775:         J[19][5] = cse718;
# 2776:         J[19][6] = cse718;
# 2777:         J[19][7] = cse718;
# 2778:         J[19][8] = cse718;
# 2779:         J[19][9] = cse718 + 4.5299999999999999e-10*nden[25];
# 2780:         J[19][10] = cse331 + cse531 + cse718 + cse754 + cse767;
# 2781:         J[19][11] = cse718;
# 2782:         J[19][12] = cse718;
# 2783:         J[19][13] = cse718;
# 2784:         J[19][14] = cse354 + cse519 + cse718 + cse819 + cse824;
# 2785:         J[19][15] = cse718;
# 2786:         J[19][16] = cse779;
# 2787:         J[19][17] = cse383 + cse718;
# 2788:         J[19][18] = cse177*nden[1] + cse718 + cse857;
# 2789:         J[19][19] = -8.0*crate - cse385 - cse613 - cse661 - cse745 - cse781;
# 2790:         J[19][20] = cse827;
# 2791:         J[19][21] = cse830;
# 2792:         J[19][22] = cse831;
# 2793:         J[19][23] = 421.0*crate + cse718;
# 2794:         J[19][24] = cse718 + cse858;
# 2795:         J[19][25] = cse789 + 4.5299999999999999e-10*nden[9];
# 2796:         J[19][26] = -cse674 - cse745;
# 2797:         J[19][27] = cse718;
# 2798:         J[19][28] = cse718;
# 2799:         J[19][29] = cse429 + cse718;
# 2800:         J[19][30] = cse718;
# 2801:         J[19][31] = cse718;
# 2802:         J[19][32] = cse718;
# 2803:         J[19][33] = cse718;
# 2804:         J[19][34] = cse718;
# 2805:         J[19][35] = cse834;
# 2806:         J[19][36] = cse792;
# 2807:         J[20][0] = cse59 + cse720;
# 2808:         J[20][1] = cse860*nden[28] + cse861*nden[30];
# 2809:         J[20][2] = -cse201;
# 2810:         J[20][6] = -cse261 + cse283;
# 2811:         J[20][8] = cse526;
# 2812:         J[20][10] = -cse327 + cse757;
# 2813:         J[20][14] = -cse540 + cse817 - cse821;
# 2814:         J[20][20] = -cse386 - cse387 - cse394 - cse553 - cse783;
# 2815:         J[20][21] = cse862;
# 2816:         J[20][28] = cse860*nden[1];
# 2817:         J[20][30] = cse861*nden[1];
# 2818:         J[20][35] = cse445;
# 2819:         J[21][0] = -cse58;
# 2820:         J[21][1] = cse863*nden[30];
# 2821:         J[21][2] = -cse576;
# 2822:         J[21][4] = -cse594;
# 2823:         J[21][6] = cse519 + cse638;
# 2824:         J[21][10] = cse646;
# 2825:         J[21][14] = -cse820;
# 2826:         J[21][20] = cse391;
# 2827:         J[21][21] = -cse396 - cse554 - cse582 - cse614 - cse829 - cse862;
# 2828:         J[21][30] = cse863*nden[1];
# 2829:         J[21][35] = cse567;
# 2830:         J[22][0] = cse864;
# 2831:         J[22][1] = cse864;
# 2832:         J[22][2] = cse864;
# 2833:         J[22][3] = cse864;
# 2834:         J[22][4] = cse742 + cse864;
# 2835:         J[22][5] = cse864;
# 2836:         J[22][6] = cse864;
# 2837:         J[22][7] = cse864;
# 2838:         J[22][8] = cse864;
# 2839:         J[22][9] = cse864;
# 2840:         J[22][10] = cse327 + 1.1844699462694885e-18*cse749 + 9.9267897819332661e-27*cse751 + 2.7912428321889765e-30*cse752 + cse864;
# 2841:         J[22][11] = cse864;
# 2842:         J[22][12] = cse864;
# 2843:         J[22][13] = cse769 + cse864;
# 2844:         J[22][14] = cse777 + cse864;
# 2845:         J[22][15] = cse864;
# 2846:         J[22][16] = cse864;
# 2847:         J[22][17] = cse864;
# 2848:         J[22][18] = cse864;
# 2849:         J[22][19] = cse864;
# 2850:         J[22][20] = cse386 + cse864;
# 2851:         J[22][21] = cse864;
# 2852:         J[22][22] = -237.0*crate + 4.9633948909666331e-27*cse721*cse722 + 1.3956214160944883e-30*cse721*cse726*cse727 - 1.5e-10*cse784 - cse787;
# 2853:         J[22][23] = cse864;
# 2854:         J[22][24] = cse864;
# 2855:         J[22][25] = cse864;
# 2856:         J[22][26] = cse864;
# 2857:         J[22][27] = cse864;
# 2858:         J[22][28] = cse864;
# 2859:         J[22][29] = cse864;
# 2860:         J[22][30] = cse864;
# 2861:         J[22][31] = cse864;
# 2862:         J[22][32] = cse864;
# 2863:         J[22][33] = cse864;
# 2864:         J[22][34] = cse864;
# 2865:         J[22][35] = cse864;
# 2866:         J[22][36] = cse864;
# 2867:         J[23][14] = cse340;
# 2868:         J[23][21] = cse396;
# 2869:         J[23][23] = -1591.0*crate;
# 2870:         J[24][0] = -cse142 + cse66 + cse67;
# 2871:         J[24][1] = cse67 + cse865*nden[33];
# 2872:         J[24][2] = -cse199;
# 2873:         J[24][3] = cse67;
# 2874:         J[24][4] = -cse171 - cse595;
# 2875:         J[24][5] = cse67;
# 2876:         J[24][6] = cse111 + cse287 + cse67;
# 2877:         J[24][7] = cse67;
# 2878:         J[24][8] = cse524 + cse67;
# 2879:         J[24][9] = -cse316 - cse693;
# 2880:         J[24][10] = cse67;
# 2881:         J[24][11] = cse67;
# 2882:         J[24][12] = cse67;
# 2883:         J[24][13] = cse67;
# 2884:         J[24][14] = cse67;
# 2885:         J[24][15] = cse67;
# 2886:         J[24][16] = cse546 + cse67 + 4.9498918425228625e-15*cse842 + cse843;
# 2887:         J[24][17] = cse67;
# 2888:         J[24][18] = -cse171 - cse856;
# 2889:         J[24][19] = cse67;
# 2890:         J[24][20] = cse67;
# 2891:         J[24][21] = cse67;
# 2892:         J[24][22] = cse67;
# 2893:         J[24][23] = cse67;
# 2894:         J[24][24] = -cse171 - cse616 - cse709 - cse844 - cse866 - cse867;
# 2895:         J[24][25] = cse67;
# 2896:         J[24][26] = -cse171 - cse670;
# 2897:         J[24][27] = cse67;
# 2898:         J[24][28] = cse67;
# 2899:         J[24][29] = cse67;
# 2900:         J[24][30] = cse67;
# 2901:         J[24][31] = cse67;
# 2902:         J[24][32] = cse67;
# 2903:         J[24][33] = cse588 + cse67 + cse865*nden[1];
# 2904:         J[24][34] = cse67;
# 2905:         J[24][35] = cse67;
# 2906:         J[24][36] = cse571 + cse67;
# 2907:         J[25][0] = -cse140 - cse868;
# 2908:         J[25][1] = cse869;
# 2909:         J[25][2] = -cse217 - cse868;
# 2910:         J[25][3] = cse869;
# 2911:         J[25][4] = -cse590 - cse868;
# 2912:         J[25][5] = cse869;
# 2913:         J[25][6] = -cse636 - cse868;
# 2914:         J[25][7] = cse869;
# 2915:         J[25][8] = cse869;
# 2916:         J[25][9] = -cse692 - cse868;
# 2917:         J[25][10] = -cse764 - cse810 - cse868;
# 2918:         J[25][11] = cse869;
# 2919:         J[25][12] = cse869;
# 2920:         J[25][13] = cse869;
# 2921:         J[25][14] = cse363 + 1.195018127472968e-23*cse811 + 5.5200000000000001e-31*cse814 + cse869;
# 2922:         J[25][15] = cse869;
# 2923:         J[25][16] = cse370 + cse869;
# 2924:         J[25][17] = cse869;
# 2925:         J[25][18] = cse869;
# 2926:         J[25][19] = cse869;
# 2927:         J[25][20] = cse869;
# 2928:         J[25][21] = cse869;
# 2929:         J[25][22] = cse869;
# 2930:         J[25][23] = cse869;
# 2931:         J[25][24] = cse869;
# 2932:         J[25][25] = -867.0*crate - cse411 - cse557 - 6.9999999999999996e-10*cse583 - cse617 - cse664 - cse710 - cse788 - cse846 - cse868;
# 2933:         J[25][26] = cse869;
# 2934:         J[25][27] = cse869;
# 2935:         J[25][28] = -cse847 - cse868;
# 2936:         J[25][29] = cse869;
# 2937:         J[25][30] = cse869;
# 2938:         J[25][31] = cse869;
# 2939:         J[25][32] = cse869;
# 2940:         J[25][33] = cse869;
# 2941:         J[25][34] = cse869 + cse870;
# 2942:         J[25][35] = cse869;
# 2943:         J[25][36] = cse869;
# 2944:         J[26][0] = -cse48;
# 2945:         J[26][1] = -cse470;
# 2946:         J[26][2] = cse574;
# 2947:         J[26][6] = cse637;
# 2948:         J[26][7] = cse301;
# 2949:         J[26][10] = -cse753;
# 2950:         J[26][14] = -cse813;
# 2951:         J[26][16] = -cse655;
# 2952:         J[26][19] = -cse661;
# 2953:         J[26][24] = -cse663;
# 2954:         J[26][26] = -cse559 - cse675 - cse679 - cse790 - cse833;
# 2955:         J[27][0] = cse147 + cse689;
# 2956:         J[27][1] = cse738;
# 2957:         J[27][2] = cse209;
# 2958:         J[27][4] = cse246;
# 2959:         J[27][6] = -cse259 + cse289;
# 2960:         J[27][7] = cse298;
# 2961:         J[27][9] = cse311 + cse312;
# 2962:         J[27][10] = cse649 + cse755;
# 2963:         J[27][14] = -cse356;
# 2964:         J[27][18] = cse526;
# 2965:         J[27][20] = cse392 + cse551;
# 2966:         J[27][21] = cse403;
# 2967:         J[27][26] = cse665;
# 2968:         J[27][27] = -cse424 - cse426 - cse428 - cse429 - cse585;
# 2969:         J[27][28] = cse871;
# 2970:         J[27][30] = cse676;
# 2971:         J[28][0] = -cse147 - cse872;
# 2972:         J[28][1] = -cse453;
# 2973:         J[28][2] = cse208;
# 2974:         J[28][6] = -cse293 + cse641;
# 2975:         J[28][9] = cse643;
# 2976:         J[28][10] = cse323;
# 2977:         J[28][14] = -cse339;
# 2978:         J[28][21] = cse402 + cse554;
# 2979:         J[28][25] = -cse845;
# 2980:         J[28][26] = cse417;
# 2981:         J[28][27] = cse424;
# 2982:         J[28][28] = -cse433 - cse560 - cse859 - cse871;
# 2983:         J[28][30] = cse677;
# 2984:         J[29][0] = -cse125 + cse873;
# 2985:         J[29][1] = cse737 + cse873;
# 2986:         J[29][2] = cse873;
# 2987:         J[29][3] = cse873;
# 2988:         J[29][4] = cse873;
# 2989:         J[29][5] = cse873;
# 2990:         J[29][6] = cse873;
# 2991:         J[29][7] = cse873;
# 2992:         J[29][8] = cse873;
# 2993:         J[29][9] = cse698 + cse873 + 3.4200000000000001e-10*nden[25];
# 2994:         J[29][10] = cse688 + cse701 + cse756;
# 2995:         J[29][11] = cse873;
# 2996:         J[29][12] = cse873;
# 2997:         J[29][13] = cse797 + cse873;
# 2998:         J[29][14] = cse356 + cse705 + cse873;
# 2999:         J[29][15] = cse873;
# 3000:         J[29][16] = cse707 + cse735;
# 3001:         J[29][17] = cse873;
# 3002:         J[29][18] = cse873;
# 3003:         J[29][19] = cse550 + cse873;
# 3004:         J[29][20] = cse873;
# 3005:         J[29][21] = cse873;
# 3006:         J[29][22] = cse688 + cse799;
# 3007:         J[29][23] = cse873;
# 3008:         J[29][24] = cse873;
# 3009:         J[29][25] = cse832 + cse873;
# 3010:         J[29][26] = cse873;
# 3011:         J[29][27] = cse428 + cse873;
# 3012:         J[29][28] = cse873;
# 3013:         J[29][29] = cse561 + cse711 + cse735;
# 3014:         J[29][30] = cse873;
# 3015:         J[29][31] = cse873;
# 3016:         J[29][32] = cse873;
# 3017:         J[29][33] = cse873;
# 3018:         J[29][34] = cse870 + cse873;
# 3019:         J[29][35] = cse873;
# 3020:         J[29][36] = cse873;
# 3021:         J[30][0] = cse872;
# 3022:         J[30][1] = -cse464;
# 3023:         J[30][6] = cse293;
# 3024:         J[30][14] = -cse650;
# 3025:         J[30][28] = cse433;
# 3026:         J[30][30] = -2.0000000000000001e-9*cse373 - cse436 - cse562 - cse566;
# 3027:         J[31][1] = cse807;
# 3028:         J[31][2] = cse235;
# 3029:         J[31][4] = cse251;
# 3030:         J[31][6] = cse284 - cse285;
# 3031:         J[31][7] = cse299;
# 3032:         J[31][13] = cse336;
# 3033:         J[31][14] = cse355 + cse653;
# 3034:         J[31][16] = cse376 + cse547;
# 3035:         J[31][24] = cse409;
# 3036:         J[31][26] = cse666;
# 3037:         J[31][31] = -cse438 - cse440 - cse586;
# 3038:         J[31][32] = cse444;
# 3039:         J[31][33] = cse588;
# 3040:         J[32][1] = -cse455;
# 3041:         J[32][2] = cse198;
# 3042:         J[32][4] = cse251;
# 3043:         J[32][6] = cse285 - cse292;
# 3044:         J[32][9] = cse744;
# 3045:         J[32][14] = cse348;
# 3046:         J[32][16] = cse655;
# 3047:         J[32][24] = cse409 + cse867 + 2.4e-10*nden[9];
# 3048:         J[32][26] = cse416 + cse671;
# 3049:         J[32][31] = cse438;
# 3050:         J[32][32] = -cse211 - 3.0e-10*cse443 - cse563;
# 3051:         J[32][33] = 7.5e-12*cse443;
# 3052:         J[33][1] = -cse466;
# 3053:         J[33][6] = cse292;
# 3054:         J[33][10] = cse854;
# 3055:         J[33][18] = cse856;
# 3056:         J[33][24] = cse866;
# 3057:         J[33][26] = cse670;
# 3058:         J[33][32] = cse211;
# 3059:         J[33][33] = -8.2499999999999999e-11*cse443 - cse564 - cse678;
# 3060:         J[34][1] = -cse458;
# 3061:         J[34][2] = cse217;
# 3062:         J[34][4] = 3.3000000000000002e-11*nden[25];
# 3063:         J[34][10] = -cse748;
# 3064:         J[34][25] = cse411 + cse558 + 3.3000000000000002e-11*nden[4];
# 3065:         J[34][34] = -cse565 - cse791;
# 3066:         J[35][0] = -cse57;
# 3067:         J[35][1] = cse450;
# 3068:         J[35][2] = cse740;
# 3069:         J[35][6] = cse874;
# 3070:         J[35][10] = cse530;
# 3071:         J[35][14] = cse874;
# 3072:         J[35][35] = -cse446 - cse569;
# 3073:         J[36][0] = cse875;
# 3074:         J[36][1] = cse451;
# 3075:         J[36][2] = cse808;
# 3076:         J[36][6] = cse875;
# 3077:         J[36][10] = -cse531;
# 3078:         J[36][14] = cse541;
# 3079:         J[36][36] = -cse446 - cse573;
# 3080:
# 3081:         // PREPROCESS_END
# 3082:     }
# 3083: };

# %% [markdown]
# ## Step 6: Building and Running Instructions
#
# Here's how to build and run the generated C++ code:

# %% [markdown]
# * **Configure the build with CMake:**

# %%
!   cmake -S . -B build -DCMAKE_CXX_COMPILER=clang++
# Out:
# -- Configuring done (0.9s)
# -- Generating done (0.0s)
# -- Build files have been written to: /home/anish/External/programming/research/jaff/worktrees/feature_radiation_codegen/examples/build

# %%
assert _exit_code == 0

# %% [markdown]
# * **Build with parallel compilation:**

# %%
!   cmake --build build -j
# Out:
# [ 50%] Building CXX object CMakeFiles/chemistry_ode.dir/chemistry_ode.cpp.o
# [100%] Linking CXX executable chemistry_ode
# [100%] Built target chemistry_ode

# %%
assert _exit_code == 0

# %% [markdown]
# * **Run the chemistry solver:**

# %%
!   ./build/chemistry_ode --analytic-jac
# Out:
# Solving Chemistry ODE System (header-only integrators)
# Number of species: 37
# Number of reactions: 287
# Time interval: [0, 3.15576e+09] seconds
# Initial conditions:
#   nden[0] = 1e-06
#   nden[1] = 1e-10
#   nden[2] = 1e-10
#   nden[3] = 1e-10
#   nden[4] = 1e-10
#   nden[5] = 1e-10
#   nden[6] = 1e-10
#   nden[7] = 1e-10
#   nden[8] = 1e-10
#   nden[9] = 1e-10
#   nden[10] = 1e-10
#   nden[11] = 1e-10
#   nden[12] = 1e-10
#   nden[13] = 1e-10
#   nden[14] = 1e-10
#   nden[15] = 1e-10
#   nden[16] = 1e-10
#   nden[17] = 1e-10
#   nden[18] = 1e-10
#   nden[19] = 1e-10
#   nden[20] = 1e-10
#   nden[21] = 1e-10
#   nden[22] = 1e-10
#   nden[23] = 1e-10
#   nden[24] = 1e-10
#   nden[25] = 1e-10
#   nden[26] = 1e-10
#   nden[27] = 1e-10
#   nden[28] = 1e-10
#   nden[29] = 1e-10
#   nden[30] = 1e-10
#   nden[31] = 1e-10
#   nden[32] = 1e-10
#   nden[33] = 1e-10
#   nden[34] = 1e-10
#   nden[35] = 1e-10
#   nden[36] = 1e-10
# Jacobian: analytic
#
# Final solution at t = 3155760000 seconds:
#   nden[0] = 1.000355681e-06
#   nden[1] = 4.37593792e-10
#   nden[2] = 1.520577576e-10
#   nden[3] = 9.999999993e-11
#   nden[4] = 1.000000001e-10
#   nden[5] = 1e-10
#   nden[6] = 1.355703992e-10
#   nden[7] = 6.093480603e-11
#   nden[8] = 1.505620826e-24
#   nden[9] = 1.116757554e-10
#   nden[10] = 2.737060871e-10
#   nden[11] = 1.000006981e-10
#   nden[12] = 9.999999977e-11
#   nden[13] = 1.012087328e-10
#   nden[14] = 2.866222455e-10
#   nden[15] = 9.999930209e-11
#   nden[16] = 1.086505709e-10
#   nden[17] = 9.999998545e-11
#   nden[18] = 1.000047601e-10
#   nden[19] = 9.816937876e-11
#   nden[20] = 5.650452394e-11
#   nden[21] = 5.510083265e-11
#   nden[22] = 9.436724163e-11
#   nden[23] = 9.999347316e-11
#   nden[24] = 7.11340122e-11
#   nden[25] = 6.91042052e-11
#   nden[26] = 9.995893379e-11
#   nden[27] = 1.663335225e-10
#   nden[28] = 1.182065569e-10
#   nden[29] = 9.999974005e-11
#   nden[30] = 3.157090083e-11
#   nden[31] = 1.042171628e-10
#   nden[32] = 9.310581655e-11
#   nden[33] = 9.795440642e-11
#   nden[34] = 1.003656525e-10
#   nden[35] = -1.200506335e-22
#   nden[36] = -4.894598334e-26
#
# Element/charge conservation:
#   C: init=1.5000000000e-09, final=1.5000000000e-09, rel_delta=3.9810759624e-15
#   H: init=1.0030000000e-06, final=1.0030000000e-06, rel_delta=3.3365562944e-15
#   He: init=3.0000000000e-10, final=3.0000000000e-10, rel_delta=-2.0851844608e-14
#   O: init=1.7000000000e-09, final=1.7000000000e-09, rel_delta=6.4715550064e-15
#   Si: init=3.0000000000e-10, final=3.0000000000e-10, rel_delta=4.7390555928e-16
#   net_charge: init=1.7000000000e-09, final=1.7000000000e-09, rel_delta=-4.0236435156e-15
#
# Integrator stats:
#   Steps taken: 4728

# %%
assert _exit_code == 0

# %% [markdown]
# * **Or, run with custom time interval (1e12 seconds):**

# %%
!   ./build/chemistry_ode --analytic-jac 1e12
# Out:
# Solving Chemistry ODE System (header-only integrators)
# Number of species: 37
# Number of reactions: 287
# Time interval: [0, 1e+12] seconds
# Initial conditions:
#   nden[0] = 1e-06
#   nden[1] = 1e-10
#   nden[2] = 1e-10
#   nden[3] = 1e-10
#   nden[4] = 1e-10
#   nden[5] = 1e-10
#   nden[6] = 1e-10
#   nden[7] = 1e-10
#   nden[8] = 1e-10
#   nden[9] = 1e-10
#   nden[10] = 1e-10
#   nden[11] = 1e-10
#   nden[12] = 1e-10
#   nden[13] = 1e-10
#   nden[14] = 1e-10
#   nden[15] = 1e-10
#   nden[16] = 1e-10
#   nden[17] = 1e-10
#   nden[18] = 1e-10
#   nden[19] = 1e-10
#   nden[20] = 1e-10
#   nden[21] = 1e-10
#   nden[22] = 1e-10
#   nden[23] = 1e-10
#   nden[24] = 1e-10
#   nden[25] = 1e-10
#   nden[26] = 1e-10
#   nden[27] = 1e-10
#   nden[28] = 1e-10
#   nden[29] = 1e-10
#   nden[30] = 1e-10
#   nden[31] = 1e-10
#   nden[32] = 1e-10
#   nden[33] = 1e-10
#   nden[34] = 1e-10
#   nden[35] = 1e-10
#   nden[36] = 1e-10
# Jacobian: analytic
#
# Final solution at t = 1e+12 seconds:
#   nden[0] = 1.00145815e-06
#   nden[1] = 1.466593952e-09
#   nden[2] = 6.996983019e-10
#   nden[3] = 9.999940149e-11
#   nden[4] = 1.000006018e-10
#   nden[5] = 9.999999668e-11
#   nden[6] = 6.028497694e-11
#   nden[7] = 2.816182587e-14
#   nden[8] = 1.478679432e-24
#   nden[9] = 1.10008923e-09
#   nden[10] = 2.207727964e-13
#   nden[11] = 1.002214834e-10
#   nden[12] = 9.999966266e-11
#   nden[13] = 1.18268595e-10
#   nden[14] = 8.21270856e-10
#   nden[15] = 9.977885392e-11
#   nden[16] = 9.932052941e-15
#   nden[17] = 9.998514706e-11
#   nden[18] = 1.014645737e-10
#   nden[19] = 3.987806331e-13
#   nden[20] = 7.330489542e-27
#   nden[21] = 7.288393525e-31
#   nden[22] = 1.062642239e-18
#   nden[23] = 9.795294263e-11
#   nden[24] = 2.735946688e-15
#   nden[25] = 1.183964232e-23
#   nden[26] = 8.779067513e-11
#   nden[27] = 2.449304192e-19
#   nden[28] = 8.022570419e-23
#   nden[29] = 9.988855078e-11
#   nden[30] = 2.153861756e-32
#   nden[31] = 1.58295956e-10
#   nden[32] = 5.034765379e-15
#   nden[33] = 1.429819786e-13
#   nden[34] = 1.011569567e-10
#   nden[35] = 7.46642079e-30
#   nden[36] = 1.24114759e-26
#
# Element/charge conservation:
#   C: init=1.5000000000e-09, final=1.5000000000e-09, rel_delta=4.2941632858e-15
#   H: init=1.0030000000e-06, final=1.0030000000e-06, rel_delta=2.0186753184e-15
#   He: init=3.0000000000e-10, final=3.0000000000e-10, rel_delta=-2.0507186020e-14
#   O: init=1.7000000000e-09, final=1.7000000000e-09, rel_delta=5.7180499188e-15
#   Si: init=3.0000000000e-10, final=3.0000000000e-10, rel_delta=1.2924697071e-16
#   net_charge: init=1.7000000000e-09, final=1.7000000000e-09, rel_delta=-5.9913336101e-15
#
# Integrator stats:
#   Steps taken: 4990

# %%
assert _exit_code == 0
