# %% [markdown]
# ## Rate table generation example

# %% [markdown]
# This is a very big network designed to stress-test the code. There are ~8200 reactions in this network. The resulting table is 726 MiB.

# %%
from jaff import Network

# Load network
network = Network("../networks/kida_uva_2024/gas_reactions_kida.uva.2024.jet")

# Export with custom settings
network.write_table(
    fname="kida_rates.hdf5",
    T_min=5.0,  # Very low temperature
    T_max=5000.0,  # High temperature
    nT=128,  # Start with 128 points
    err_tol=0.02,  # 2% accuracy
    rate_min=1e-40,  # Very small rates
    rate_max=1e-5,  # Clip large rates
    fast_log=True,  # Use fast_log sampling
    format="hdf5",  # Output table in HDF5 format
    include_all=False,  # Only tabulated reactions
    verbose=True,  # Show progress
)
# Out:
# ░░█ ▄▀█ █▀▀ █▀▀
# █▄█ █▀█ █▀░ █▀░
#
# Just Another Functional Format!
#
# INFO     Loading network from /home/anish/External/programming/research/jaff/worktrees/feature_table_interpolation/networks/kida_uva_2024/gas_reactions_kida.uva.2024.jet
# INFO     Network label: gas_reactions_kida.uva.2024
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO     Variables found: av, crate, tgas
# INFO     Loaded 8275 reactions
# INFO     Loaded 0 photo-chemistry reactions
# INFO     Sink: C9H4
# INFO     Sink: NH2CO
# INFO     Sink: C6H3
# INFO     Sink: O3
# INFO     Sink: HCOCHO
# INFO     Sink: C7H3
# INFO     Sink: MgH2
# INFO     Sink: C7H4
# INFO     Sink: FeH
# INFO     Sink: C9H3
# INFO     Sink: C8H4
# INFO     Sink: HSO
# INFO     Sink: NHCHO
# INFO     Sink: C5H3
# INFO     Sink: HOCO
# INFO     Sink: C8H3
# INFO     Sink: C5H4
# INFO     Sink: HOCHN
# INFO     Sink: HCOCO
# INFO     Sink: NH2CH2OH
# INFO     Sink: H2S3
# WARNING  Sink detected
# WARNING  Electron recombination not found for F+
# WARNING  Isomers detected: CH3COCH3, C2H5CHO
# WARNING  Isomers detected: CH3C6H, C7H4
# WARNING  Isomers detected: CH3CCH, CH2CCH2
# WARNING  Isomers detected: HCN, HNC
# WARNING  Isomers detected: HCN+, HNC+
# WARNING  Isomers detected: HCO+, HOC+
# WARNING  Isomers detected: HCS+, CSH+
# WARNING  Isomers detected: OCN, CNO
# WARNING  Isomers detected: HC3N, HCNCC, HCCNC, HNCCC
# WARNING  Isomers detected: CH3CH2OH, CH3OCH3
# WARNING  Isomers detected: C2H5OH+, CH3OCH3+
# WARNING  Isomers detected: CH3C4H, C5H4
# WARNING  Isomers detected: HNCO, HOCN, HCNO, HONC
# WARNING  Isomers detected: CH3S, CH2SH
# WARNING  Isomers detected: CNC+, C2N+
# WARNING  Isomers detected: HCNH+, H2NC+
# WARNING  Isomers detected: CH3OCH4+, C2H5OH2+
# WARNING  Isomers detected: HNCO+, HOCN+, HCNO+, HONC+
# WARNING  Isomers detected: HNCS+, HSCN+, HCNS+
# WARNING  Isomers detected: HC3NH+, HC2NCH+
# WARNING  Isomers detected: CH3O, CH2OH
# WARNING  Isomers detected: HCCCHO, H2C3O
# WARNING  Isomers detected: H2NCS+, HNCSH+, H2SCN+, H2CNS+, HCNSH+
# WARNING  Isomers detected: HNCS, NCSH, HSCN, HCNS
# WARNING  Isomers detected: H2NCO+, HNCOH+, H2OCN+, HCNOH+, H2CNO+
# WARNING  Isomers detected: HCCCHOH+, C2H3CO+
# WARNING  Isomers detected: CNCN, C2N2
# WARNING  Isomers detected: NHCHO, HOCHN, NH2CO
# WARNING  Duplicate reaction found: N2 -> N + N
# WARNING  Duplicate reaction found: N -> N+ + e-
# WARNING  Duplicate reaction found: O -> O+ + e-
# WARNING  Duplicate reaction found: CO -> C + O
# WARNING  Duplicate reaction found: HCCP -> H + CCP
# WARNING  Duplicate reaction found: H2CN -> H + HCN
# WARNING  Duplicate reaction found: NH2CN -> CN + NH2
# WARNING  Duplicate reaction found: CH3NCO -> OCN + CH3
# WARNING  Duplicate reaction found: He+ + CS2 -> CS2+ + He
# WARNING  Duplicate reaction found: N+ + CS2 -> CS2+ + N
# WARNING  Duplicate reaction found: H2+ + CS2 -> CS2+ + H2
# WARNING  Duplicate reaction found: H2+ + CS2 -> HCS2+ + H
# WARNING  Duplicate reaction found: OH+ + CS2 -> HCS2+ + O
# WARNING  Duplicate reaction found: H3+ + CS2 -> HCS2+ + H2
# WARNING  Duplicate reaction found: HCS2+ + e- -> CS2 + H
# WARNING  Duplicate reaction found: CS2+ + H -> H+ + CS2
# WARNING  Duplicate reaction found: CS2+ + O -> O+ + CS2
# WARNING  Duplicate reaction found: CS2+ + O2 -> O2+ + CS2
# WARNING  Duplicate reaction found: CS2+ + H2O -> H2O+ + CS2
# WARNING  Duplicate reaction found: CS2+ + H2S -> H2S+ + CS2
# WARNING  Duplicate reaction found: HCS2+ + C -> CH+ + CS2
# WARNING  Duplicate reaction found: HCS2+ + H2O -> H3O+ + CS2
# WARNING  Duplicate reaction found: HCS2+ + C2H2 -> C2H3+ + CS2
# WARNING  Duplicate reaction found: HCS2+ + CH4 -> CH5+ + CS2
# WARNING  Duplicate reaction found: CS2+ + H2 -> HCS2+ + H
# WARNING  Duplicate reaction found: CS2+ + H2O -> HCS2+ + OH
# WARNING  Duplicate reaction found: NH2CH2OH -> NH2CH2O + H
# WARNING  Duplicate reaction found: NH2CH2OH -> NH2CH2O + H
# WARNING  Duplicate reaction found: CNCN + H3+ -> H2 + C2N2H+
# WARNING  Duplicate reaction found: FeH -> Fe + H
# WARNING  Duplicate reaction found: MgH2 -> MgH + H
# WARNING  Duplicate reaction found: C5H3 -> C5H2 + H
# WARNING  Duplicate reaction found: C6H3 -> C6H2 + H
# WARNING  Duplicate reaction found: C7H3 -> C7H2 + H
# WARNING  Duplicate reaction found: C8H3 -> C8H2 + H
# WARNING  Duplicate reaction found: C9H3 -> C9H2 + H
# WARNING  Duplicate reaction found: C5H4 -> C5H2 + H2
# WARNING  Duplicate reaction found: C6H4 -> C6H2 + H2
# WARNING  Duplicate reaction found: C7H4 -> C7H2 + H2
# WARNING  Duplicate reaction found: C8H4 -> C8H2 + H2
# WARNING  Duplicate reaction found: C9H4 -> C9H2 + H2
# WARNING  Duplicate reaction found: HCCS -> CS + CH
# WARNING  Duplicate reaction found: CH2OH -> CH2 + OH
# WARNING  Duplicate reaction found: CH3O -> CH3 + O
# WARNING  Duplicate reaction found: HC3S -> CS + CCH
# WARNING  Duplicate reaction found: CH2CCH2 -> CH2 + C2H2
# WARNING  Duplicate reaction found: CH3CHS -> CH2 + H2CS
# WARNING  Duplicate reaction found: CH3OCH2 -> H2CO + CH3
# WARNING  Duplicate reaction found: CH3OCH2 -> CH3CHOH+ + e-
# INFO     Network loaded successfully!
# /home/anish/External/programming/research/jaff/worktrees/feature_table_interpolation/src/jaff/core/io.py:443: RuntimeWarning: divide by zero encountered in log
#   react_func.append(np.log(float(r)))
# /home/anish/External/programming/research/jaff/worktrees/feature_table_interpolation/src/jaff/core/io.py:443: RuntimeWarning: invalid value encountered in log
#   react_func.append(np.log(float(r)))
# INFO     nTemp = 255, max_err = 0.7976079932124195 in reaction l-C3H2 + HCNH+ -> HNC + l-C3H3+ at T = 25.684547244094485
# INFO     nTemp = 509, max_err = 0.5825915271118252 in reaction CS + C+ -> C + CS+ at T = 6.962736835629918
# INFO     nTemp = 1017, max_err = 0.1606732552219363 in reaction H + H2 -> H + H + H at T = 60.82209645669292
# INFO     nTemp = 2033, max_err = 0.12750347684144794 in reaction C + CN -> N + C2 at T = 37.42627337598423
# INFO     nTemp = 4065, max_err = 0.03418306144160854 in reaction H2 + C2H2+ -> H + C2H3+ at T = 12.991326279527565
# INFO     nTemp = 8129, max_err = 0.024413384609781832 in reaction CS + C+ -> C + CS+ at T = 6.9970847302534445
# INFO     nTemp = 16257, max_err = 0.00975981909084953 in reaction H + HCNH+ -> H2 + HCN+ at T = 51.98978069635827
